# %%
# %matplotlib inline
import pandas as pd
import lightgbm as lgb
import numpy as np
import os
from __future__ import division
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.model_selection import ParameterGrid
import datetime
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
df_train=pd.read_csv('data/atec_anti_fraud_train.csv', parse_dates=['date'])

# %%
df_train_clean=df_train.loc[df_train['label']!=-1]
del df_train

# %%
y=df_train_clean['label']
X=df_train_clean.drop(['id','label','date'],axis=1)
cut_date_train=datetime.datetime(2017,10,20)
cut_date_test=datetime.datetime(2017,11,1)

# %%
x_train=X[df_train_clean.date<=cut_date_train]
x_test=X[df_train_clean.date>=cut_date_test]
y_train=y[df_train_clean.date<=cut_date_train]
y_test=y[df_train_clean.date>=cut_date_test]

# %%
num_values=2000
category_feature=[]
for i in range(X.shape[1]):
    num = X['f'+str(i+1)].unique().shape[0]
    if num <=num_values:
        category_feature.append(i)

# %%
del df_train_clean, X, y

# %%
def atec_metric(preds, train_data):
    labels = train_data.get_label()
    fpr,tpr,threshhold=roc_curve(labels, preds)
    return 'atec_metric', 0.4*tpr[fpr<=0.001][-1] + 0.3*tpr[fpr<=0.005][-1] + 0.3*tpr[fpr<=0.01][-1], True

# %%
feature_name=['feasture_'+str(col+1) for col in range(x_train.shape[1])]
lgb_train=lgb.Dataset(x_train,y_train,free_raw_data=False,feature_name=feature_name, categorical_feature=category_feature)
lgb_valid=lgb.Dataset(x_test,y_test,reference=lgb_train,free_raw_data=False,feature_name=feature_name, categorical_feature=category_feature)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'device': 'cpu',
    'verbose': 0,
    'early_stopping_round': 100,
    'learning_rate': 0.01,
    'num_leaves': 128,
    'lambda_l1': 0.006,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': [5],
    'bagging_seed':3,
    'feature_fration_seed':2
}

# %%
gbm = lgb.train(params, lgb_train, num_boost_round=10000, valid_sets=lgb_valid, valid_names='valid_set',feval=atec_metric)
# Out:
# C:\Users\Dong\Anaconda3\lib\site-packages\lightgbm\engine.py:104: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# C:\Users\Dong\Anaconda3\lib\site-packages\lightgbm\basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# [1]	valid_set's auc: 0.906756	valid_set's atec_metric: 0.334205
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_set's auc: 0.907598	valid_set's atec_metric: 0.357752
# [3]	valid_set's auc: 0.895386	valid_set's atec_metric: 0.365601
# [4]	valid_set's auc: 0.901819	valid_set's atec_metric: 0.365407
# [5]	valid_set's auc: 0.901023	valid_set's atec_metric: 0.374612
# [6]	valid_set's auc: 0.90524	valid_set's atec_metric: 0.392151
# [7]	valid_set's auc: 0.916416	valid_set's atec_metric: 0.403682
# [8]	valid_set's auc: 0.919101	valid_set's atec_metric: 0.402326
# [9]	valid_set's auc: 0.917304	valid_set's atec_metric: 0.407171
# [10]	valid_set's auc: 0.918454	valid_set's atec_metric: 0.410078
# [11]	valid_set's auc: 0.923234	valid_set's atec_metric: 0.411725
# [12]	valid_set's auc: 0.923265	valid_set's atec_metric: 0.417248
# [13]	valid_set's auc: 0.923234	valid_set's atec_metric: 0.409012
# [14]	valid_set's auc: 0.924214	valid_set's atec_metric: 0.413469
# [15]	valid_set's auc: 0.924058	valid_set's atec_metric: 0.41124
# [16]	valid_set's auc: 0.930034	valid_set's atec_metric: 0.412888
# [17]	valid_set's auc: 0.932712	valid_set's atec_metric: 0.420833
# [18]	valid_set's auc: 0.932384	valid_set's atec_metric: 0.42064
# [19]	valid_set's auc: 0.932612	valid_set's atec_metric: 0.426453
# [20]	valid_set's auc: 0.934989	valid_set's atec_metric: 0.426163
# [21]	valid_set's auc: 0.934946	valid_set's atec_metric: 0.423547
# [22]	valid_set's auc: 0.935464	valid_set's atec_metric: 0.421415
# [23]	valid_set's auc: 0.936138	valid_set's atec_metric: 0.424903
# [24]	valid_set's auc: 0.93624	valid_set's atec_metric: 0.424128
# [25]	valid_set's auc: 0.936427	valid_set's atec_metric: 0.426744
# [26]	valid_set's auc: 0.936388	valid_set's atec_metric: 0.425
# [27]	valid_set's auc: 0.936468	valid_set's atec_metric: 0.423547
# [28]	valid_set's auc: 0.936617	valid_set's atec_metric: 0.427229
# [29]	valid_set's auc: 0.937157	valid_set's atec_metric: 0.42936
# [30]	valid_set's auc: 0.938248	valid_set's atec_metric: 0.424903
# [31]	valid_set's auc: 0.938177	valid_set's atec_metric: 0.429554
# [32]	valid_set's auc: 0.93935	valid_set's atec_metric: 0.428585
# [33]	valid_set's auc: 0.939588	valid_set's atec_metric: 0.430911
# [34]	valid_set's auc: 0.939861	valid_set's atec_metric: 0.427713
# [35]	valid_set's auc: 0.940112	valid_set's atec_metric: 0.426357
# [36]	valid_set's auc: 0.940584	valid_set's atec_metric: 0.428876
# [37]	valid_set's auc: 0.940326	valid_set's atec_metric: 0.425775
# [38]	valid_set's auc: 0.940106	valid_set's atec_metric: 0.426744
# [39]	valid_set's auc: 0.940091	valid_set's atec_metric: 0.426066
# [40]	valid_set's auc: 0.940081	valid_set's atec_metric: 0.426453
# [41]	valid_set's auc: 0.940201	valid_set's atec_metric: 0.428391
# [42]	valid_set's auc: 0.940037	valid_set's atec_metric: 0.426357
# [43]	valid_set's auc: 0.940076	valid_set's atec_metric: 0.426163
# [44]	valid_set's auc: 0.939986	valid_set's atec_metric: 0.425678
# [45]	valid_set's auc: 0.93997	valid_set's atec_metric: 0.427132
# [46]	valid_set's auc: 0.939963	valid_set's atec_metric: 0.426357
# [47]	valid_set's auc: 0.940075	valid_set's atec_metric: 0.424709
# [48]	valid_set's auc: 0.940026	valid_set's atec_metric: 0.424322
# [49]	valid_set's auc: 0.939737	valid_set's atec_metric: 0.424419
# [50]	valid_set's auc: 0.939807	valid_set's atec_metric: 0.424516
# [51]	valid_set's auc: 0.939716	valid_set's atec_metric: 0.425484
# [52]	valid_set's auc: 0.93952	valid_set's atec_metric: 0.426066
# [53]	valid_set's auc: 0.941642	valid_set's atec_metric: 0.428973
# [54]	valid_set's auc: 0.941788	valid_set's atec_metric: 0.431105
# [55]	valid_set's auc: 0.941729	valid_set's atec_metric: 0.430136
# [56]	valid_set's auc: 0.941515	valid_set's atec_metric: 0.431589
# [57]	valid_set's auc: 0.942913	valid_set's atec_metric: 0.436434
# [58]	valid_set's auc: 0.94365	valid_set's atec_metric: 0.436725
# [59]	valid_set's auc: 0.94355	valid_set's atec_metric: 0.436822
# [60]	valid_set's auc: 0.943515	valid_set's atec_metric: 0.43595
# [61]	valid_set's auc: 0.943719	valid_set's atec_metric: 0.436919
# [62]	valid_set's auc: 0.943512	valid_set's atec_metric: 0.43624
# [63]	valid_set's auc: 0.943786	valid_set's atec_metric: 0.435853
# [64]	valid_set's auc: 0.943729	valid_set's atec_metric: 0.437306
# [65]	valid_set's auc: 0.943851	valid_set's atec_metric: 0.437597
# [66]	valid_set's auc: 0.94215	valid_set's atec_metric: 0.440601
# [67]	valid_set's auc: 0.941663	valid_set's atec_metric: 0.440213
# [68]	valid_set's auc: 0.94223	valid_set's atec_metric: 0.438469
# [69]	valid_set's auc: 0.942544	valid_set's atec_metric: 0.438469
# [70]	valid_set's auc: 0.942944	valid_set's atec_metric: 0.4375
# [71]	valid_set's auc: 0.943478	valid_set's atec_metric: 0.4375
# [72]	valid_set's auc: 0.944814	valid_set's atec_metric: 0.439922
# [73]	valid_set's auc: 0.944756	valid_set's atec_metric: 0.438275
# [74]	valid_set's auc: 0.942463	valid_set's atec_metric: 0.442539
# [75]	valid_set's auc: 0.942468	valid_set's atec_metric: 0.443217
# [76]	valid_set's auc: 0.942754	valid_set's atec_metric: 0.442345
# [77]	valid_set's auc: 0.94336	valid_set's atec_metric: 0.442636
# [78]	valid_set's auc: 0.943592	valid_set's atec_metric: 0.442151
# [79]	valid_set's auc: 0.943825	valid_set's atec_metric: 0.445349
# [80]	valid_set's auc: 0.943911	valid_set's atec_metric: 0.446512
# [81]	valid_set's auc: 0.944387	valid_set's atec_metric: 0.446415
# [82]	valid_set's auc: 0.945044	valid_set's atec_metric: 0.445155
# [83]	valid_set's auc: 0.944459	valid_set's atec_metric: 0.446027
# [84]	valid_set's auc: 0.945479	valid_set's atec_metric: 0.445543
# [85]	valid_set's auc: 0.945733	valid_set's atec_metric: 0.444574
# [86]	valid_set's auc: 0.945732	valid_set's atec_metric: 0.443217
# [87]	valid_set's auc: 0.945796	valid_set's atec_metric: 0.440891
# [88]	valid_set's auc: 0.945821	valid_set's atec_metric: 0.444186
# [89]	valid_set's auc: 0.945999	valid_set's atec_metric: 0.443217
# [90]	valid_set's auc: 0.945998	valid_set's atec_metric: 0.442733
# [91]	valid_set's auc: 0.946096	valid_set's atec_metric: 0.443023
# [92]	valid_set's auc: 0.946446	valid_set's atec_metric: 0.442054
# [93]	valid_set's auc: 0.946676	valid_set's atec_metric: 0.44438
# [94]	valid_set's auc: 0.946864	valid_set's atec_metric: 0.446512
# [95]	valid_set's auc: 0.947209	valid_set's atec_metric: 0.444767
# [96]	valid_set's auc: 0.947497	valid_set's atec_metric: 0.446318
# [97]	valid_set's auc: 0.948316	valid_set's atec_metric: 0.443605
# [98]	valid_set's auc: 0.948572	valid_set's atec_metric: 0.443314
# [99]	valid_set's auc: 0.948735	valid_set's atec_metric: 0.446318
# [100]	valid_set's auc: 0.948965	valid_set's atec_metric: 0.445252
# [101]	valid_set's auc: 0.949894	valid_set's atec_metric: 0.446512
# [102]	valid_set's auc: 0.949995	valid_set's atec_metric: 0.445736
# [103]	valid_set's auc: 0.950175	valid_set's atec_metric: 0.447481
# [104]	valid_set's auc: 0.950325	valid_set's atec_metric: 0.447771
# [105]	valid_set's auc: 0.950604	valid_set's atec_metric: 0.448547
# [106]	valid_set's auc: 0.951102	valid_set's atec_metric: 0.450678
# [107]	valid_set's auc: 0.951169	valid_set's atec_metric: 0.453101
# [108]	valid_set's auc: 0.95147	valid_set's atec_metric: 0.451066
# [109]	valid_set's auc: 0.951979	valid_set's atec_metric: 0.451647
# [110]	valid_set's auc: 0.952899	valid_set's atec_metric: 0.453488
# [111]	valid_set's auc: 0.953184	valid_set's atec_metric: 0.455911
# [112]	valid_set's auc: 0.953302	valid_set's atec_metric: 0.455426
# [113]	valid_set's auc: 0.953835	valid_set's atec_metric: 0.454457
# [114]	valid_set's auc: 0.954791	valid_set's atec_metric: 0.455426
# [115]	valid_set's auc: 0.954858	valid_set's atec_metric: 0.457364
# [116]	valid_set's auc: 0.955426	valid_set's atec_metric: 0.460465
# [117]	valid_set's auc: 0.955584	valid_set's atec_metric: 0.46095
# [118]	valid_set's auc: 0.95584	valid_set's atec_metric: 0.458624
# [119]	valid_set's auc: 0.955989	valid_set's atec_metric: 0.460078
# [120]	valid_set's auc: 0.956156	valid_set's atec_metric: 0.460659
# [121]	valid_set's auc: 0.956467	valid_set's atec_metric: 0.459399
# [122]	valid_set's auc: 0.956853	valid_set's atec_metric: 0.459593
# [123]	valid_set's auc: 0.957055	valid_set's atec_metric: 0.459012
# [124]	valid_set's auc: 0.957225	valid_set's atec_metric: 0.457267
# [125]	valid_set's auc: 0.957257	valid_set's atec_metric: 0.456977
# [126]	valid_set's auc: 0.957308	valid_set's atec_metric: 0.456686
# [127]	valid_set's auc: 0.957416	valid_set's atec_metric: 0.460078
# [128]	valid_set's auc: 0.957537	valid_set's atec_metric: 0.460756
# [129]	valid_set's auc: 0.957954	valid_set's atec_metric: 0.459884
# [130]	valid_set's auc: 0.958004	valid_set's atec_metric: 0.462016
# [131]	valid_set's auc: 0.957629	valid_set's atec_metric: 0.461047
# [132]	valid_set's auc: 0.95779	valid_set's atec_metric: 0.463081
# [133]	valid_set's auc: 0.957854	valid_set's atec_metric: 0.463081
# [134]	valid_set's auc: 0.957847	valid_set's atec_metric: 0.462209
# [135]	valid_set's auc: 0.957967	valid_set's atec_metric: 0.462694
# [136]	valid_set's auc: 0.958089	valid_set's atec_metric: 0.46657
# [137]	valid_set's auc: 0.95816	valid_set's atec_metric: 0.464244
# [138]	valid_set's auc: 0.958243	valid_set's atec_metric: 0.464922
# [139]	valid_set's auc: 0.958293	valid_set's atec_metric: 0.466376
# [140]	valid_set's auc: 0.958599	valid_set's atec_metric: 0.465504
# [141]	valid_set's auc: 0.958623	valid_set's atec_metric: 0.464922
# [142]	valid_set's auc: 0.958693	valid_set's atec_metric: 0.465795
# [143]	valid_set's auc: 0.958975	valid_set's atec_metric: 0.46531
# [144]	valid_set's auc: 0.959242	valid_set's atec_metric: 0.465988
# [145]	valid_set's auc: 0.959442	valid_set's atec_metric: 0.465891
# [146]	valid_set's auc: 0.959587	valid_set's atec_metric: 0.46657
# [147]	valid_set's auc: 0.959788	valid_set's atec_metric: 0.467248
# [148]	valid_set's auc: 0.959845	valid_set's atec_metric: 0.465601
# [149]	valid_set's auc: 0.959901	valid_set's atec_metric: 0.465698
# [150]	valid_set's auc: 0.960431	valid_set's atec_metric: 0.467248
# [151]	valid_set's auc: 0.960275	valid_set's atec_metric: 0.467054
# [152]	valid_set's auc: 0.960296	valid_set's atec_metric: 0.469186
# [153]	valid_set's auc: 0.960677	valid_set's atec_metric: 0.469767
# [154]	valid_set's auc: 0.960476	valid_set's atec_metric: 0.47064
# [155]	valid_set's auc: 0.960856	valid_set's atec_metric: 0.470833
# [156]	valid_set's auc: 0.960949	valid_set's atec_metric: 0.471027
# [157]	valid_set's auc: 0.960797	valid_set's atec_metric: 0.47093
# [158]	valid_set's auc: 0.96091	valid_set's atec_metric: 0.471609
# [159]	valid_set's auc: 0.961423	valid_set's atec_metric: 0.471899
# [160]	valid_set's auc: 0.961551	valid_set's atec_metric: 0.472578
# [161]	valid_set's auc: 0.961576	valid_set's atec_metric: 0.471124
# [162]	valid_set's auc: 0.961653	valid_set's atec_metric: 0.471802
# [163]	valid_set's auc: 0.961891	valid_set's atec_metric: 0.471705
# [164]	valid_set's auc: 0.961982	valid_set's atec_metric: 0.471221
# [165]	valid_set's auc: 0.962044	valid_set's atec_metric: 0.472481
# [166]	valid_set's auc: 0.962186	valid_set's atec_metric: 0.473353
# [167]	valid_set's auc: 0.962253	valid_set's atec_metric: 0.475872
# [168]	valid_set's auc: 0.962334	valid_set's atec_metric: 0.475678
# [169]	valid_set's auc: 0.962434	valid_set's atec_metric: 0.475775
# [170]	valid_set's auc: 0.962533	valid_set's atec_metric: 0.47655
# [171]	valid_set's auc: 0.962683	valid_set's atec_metric: 0.476453
# [172]	valid_set's auc: 0.962759	valid_set's atec_metric: 0.475872
# [173]	valid_set's auc: 0.962848	valid_set's atec_metric: 0.475097
# [174]	valid_set's auc: 0.962987	valid_set's atec_metric: 0.476938
# [175]	valid_set's auc: 0.962957	valid_set's atec_metric: 0.476453
# [176]	valid_set's auc: 0.963265	valid_set's atec_metric: 0.476841
# [177]	valid_set's auc: 0.96407	valid_set's atec_metric: 0.477519
# [178]	valid_set's auc: 0.964236	valid_set's atec_metric: 0.477713
# [179]	valid_set's auc: 0.964538	valid_set's atec_metric: 0.476841
# [180]	valid_set's auc: 0.964768	valid_set's atec_metric: 0.474903
# [181]	valid_set's auc: 0.964941	valid_set's atec_metric: 0.474322
# [182]	valid_set's auc: 0.964989	valid_set's atec_metric: 0.474806
# [183]	valid_set's auc: 0.965075	valid_set's atec_metric: 0.474612
# [184]	valid_set's auc: 0.965076	valid_set's atec_metric: 0.474128
# [185]	valid_set's auc: 0.964631	valid_set's atec_metric: 0.475
# [186]	valid_set's auc: 0.964648	valid_set's atec_metric: 0.475
# [187]	valid_set's auc: 0.96472	valid_set's atec_metric: 0.476163
# [188]	valid_set's auc: 0.964848	valid_set's atec_metric: 0.474612
# [189]	valid_set's auc: 0.964921	valid_set's atec_metric: 0.475581
# [190]	valid_set's auc: 0.964927	valid_set's atec_metric: 0.477326
# [191]	valid_set's auc: 0.965014	valid_set's atec_metric: 0.477229
# [192]	valid_set's auc: 0.966088	valid_set's atec_metric: 0.47655
# [193]	valid_set's auc: 0.966676	valid_set's atec_metric: 0.475969
# [194]	valid_set's auc: 0.966947	valid_set's atec_metric: 0.476163
# [195]	valid_set's auc: 0.967112	valid_set's atec_metric: 0.475678
# [196]	valid_set's auc: 0.967435	valid_set's atec_metric: 0.47626
# [197]	valid_set's auc: 0.967617	valid_set's atec_metric: 0.476357
# [198]	valid_set's auc: 0.967613	valid_set's atec_metric: 0.479264
# [199]	valid_set's auc: 0.967628	valid_set's atec_metric: 0.47936
# [200]	valid_set's auc: 0.967682	valid_set's atec_metric: 0.478488
# [201]	valid_set's auc: 0.967763	valid_set's atec_metric: 0.479554
# [202]	valid_set's auc: 0.968104	valid_set's atec_metric: 0.477519
# [203]	valid_set's auc: 0.968184	valid_set's atec_metric: 0.477616
# [204]	valid_set's auc: 0.968203	valid_set's atec_metric: 0.476841
# [205]	valid_set's auc: 0.968253	valid_set's atec_metric: 0.476357
# [206]	valid_set's auc: 0.968393	valid_set's atec_metric: 0.475678
# [207]	valid_set's auc: 0.968397	valid_set's atec_metric: 0.476744
# [208]	valid_set's auc: 0.968332	valid_set's atec_metric: 0.477713
# [209]	valid_set's auc: 0.968435	valid_set's atec_metric: 0.479264
# [210]	valid_set's auc: 0.968469	valid_set's atec_metric: 0.480233
# [211]	valid_set's auc: 0.968482	valid_set's atec_metric: 0.478973
# [212]	valid_set's auc: 0.968507	valid_set's atec_metric: 0.478295
# [213]	valid_set's auc: 0.968526	valid_set's atec_metric: 0.479845
# [214]	valid_set's auc: 0.968565	valid_set's atec_metric: 0.479457
# [215]	valid_set's auc: 0.968672	valid_set's atec_metric: 0.479845
# [216]	valid_set's auc: 0.968706	valid_set's atec_metric: 0.47936
# [217]	valid_set's auc: 0.968739	valid_set's atec_metric: 0.479554
# [218]	valid_set's auc: 0.968753	valid_set's atec_metric: 0.479651
# [219]	valid_set's auc: 0.968755	valid_set's atec_metric: 0.480426
# [220]	valid_set's auc: 0.968765	valid_set's atec_metric: 0.480426
# [221]	valid_set's auc: 0.968997	valid_set's atec_metric: 0.479748
# [222]	valid_set's auc: 0.969063	valid_set's atec_metric: 0.479748
# [223]	valid_set's auc: 0.969603	valid_set's atec_metric: 0.479748
# [224]	valid_set's auc: 0.969617	valid_set's atec_metric: 0.479651
# [225]	valid_set's auc: 0.969652	valid_set's atec_metric: 0.479942
# [226]	valid_set's auc: 0.969744	valid_set's atec_metric: 0.480039
# [227]	valid_set's auc: 0.969799	valid_set's atec_metric: 0.481008
# [228]	valid_set's auc: 0.969844	valid_set's atec_metric: 0.481589
# [229]	valid_set's auc: 0.969877	valid_set's atec_metric: 0.481977
# [230]	valid_set's auc: 0.969895	valid_set's atec_metric: 0.482171
# [231]	valid_set's auc: 0.968642	valid_set's atec_metric: 0.483818
# [232]	valid_set's auc: 0.968696	valid_set's atec_metric: 0.485078
# [233]	valid_set's auc: 0.968767	valid_set's atec_metric: 0.483333
# [234]	valid_set's auc: 0.968892	valid_set's atec_metric: 0.484302
# [235]	valid_set's auc: 0.968915	valid_set's atec_metric: 0.484496
# [236]	valid_set's auc: 0.9689	valid_set's atec_metric: 0.48343
# [237]	valid_set's auc: 0.969071	valid_set's atec_metric: 0.483333
# [238]	valid_set's auc: 0.969096	valid_set's atec_metric: 0.483527
# [239]	valid_set's auc: 0.969174	valid_set's atec_metric: 0.484981
# [240]	valid_set's auc: 0.969457	valid_set's atec_metric: 0.484593
# [241]	valid_set's auc: 0.969499	valid_set's atec_metric: 0.484981
# [242]	valid_set's auc: 0.969604	valid_set's atec_metric: 0.483818
# [243]	valid_set's auc: 0.969616	valid_set's atec_metric: 0.484496
# [244]	valid_set's auc: 0.969662	valid_set's atec_metric: 0.484981
# [245]	valid_set's auc: 0.969655	valid_set's atec_metric: 0.485465
# [246]	valid_set's auc: 0.969738	valid_set's atec_metric: 0.486531
# [247]	valid_set's auc: 0.968946	valid_set's atec_metric: 0.486531
# [248]	valid_set's auc: 0.968257	valid_set's atec_metric: 0.486822
# [249]	valid_set's auc: 0.968415	valid_set's atec_metric: 0.486822
# [250]	valid_set's auc: 0.968598	valid_set's atec_metric: 0.486725
# [251]	valid_set's auc: 0.968762	valid_set's atec_metric: 0.487403
# [252]	valid_set's auc: 0.968802	valid_set's atec_metric: 0.487403
# [253]	valid_set's auc: 0.968817	valid_set's atec_metric: 0.487306
# [254]	valid_set's auc: 0.968815	valid_set's atec_metric: 0.486143
# [255]	valid_set's auc: 0.968845	valid_set's atec_metric: 0.486919
# [256]	valid_set's auc: 0.968969	valid_set's atec_metric: 0.486822
# [257]	valid_set's auc: 0.969007	valid_set's atec_metric: 0.486047
# [258]	valid_set's auc: 0.969083	valid_set's atec_metric: 0.48595
# [259]	valid_set's auc: 0.969115	valid_set's atec_metric: 0.485465
# [260]	valid_set's auc: 0.969227	valid_set's atec_metric: 0.485465
# [261]	valid_set's auc: 0.969328	valid_set's atec_metric: 0.484981
# [262]	valid_set's auc: 0.969352	valid_set's atec_metric: 0.484593
# [263]	valid_set's auc: 0.969622	valid_set's atec_metric: 0.486919
# [264]	valid_set's auc: 0.969699	valid_set's atec_metric: 0.488275
# [265]	valid_set's auc: 0.969732	valid_set's atec_metric: 0.488953
# [266]	valid_set's auc: 0.969749	valid_set's atec_metric: 0.48905
# [267]	valid_set's auc: 0.969788	valid_set's atec_metric: 0.490407
# [268]	valid_set's auc: 0.969933	valid_set's atec_metric: 0.489826
# [269]	valid_set's auc: 0.969969	valid_set's atec_metric: 0.489826
# [270]	valid_set's auc: 0.969971	valid_set's atec_metric: 0.490795
# [271]	valid_set's auc: 0.970016	valid_set's atec_metric: 0.490891
# [272]	valid_set's auc: 0.970165	valid_set's atec_metric: 0.490213
# [273]	valid_set's auc: 0.970206	valid_set's atec_metric: 0.491764
# [274]	valid_set's auc: 0.970229	valid_set's atec_metric: 0.491473
# [275]	valid_set's auc: 0.970246	valid_set's atec_metric: 0.492054
# [276]	valid_set's auc: 0.970372	valid_set's atec_metric: 0.491667
# [277]	valid_set's auc: 0.970458	valid_set's atec_metric: 0.492054
# [278]	valid_set's auc: 0.970542	valid_set's atec_metric: 0.492248
# [279]	valid_set's auc: 0.970593	valid_set's atec_metric: 0.492539
# [280]	valid_set's auc: 0.970786	valid_set's atec_metric: 0.49312
# [281]	valid_set's auc: 0.970796	valid_set's atec_metric: 0.49312
# [282]	valid_set's auc: 0.970812	valid_set's atec_metric: 0.494283
# [283]	valid_set's auc: 0.97083	valid_set's atec_metric: 0.495736
# [284]	valid_set's auc: 0.970842	valid_set's atec_metric: 0.495349
# [285]	valid_set's auc: 0.970892	valid_set's atec_metric: 0.493023
# [286]	valid_set's auc: 0.970882	valid_set's atec_metric: 0.495155
# [287]	valid_set's auc: 0.970981	valid_set's atec_metric: 0.498837
# [288]	valid_set's auc: 0.971019	valid_set's atec_metric: 0.495543
# [289]	valid_set's auc: 0.971037	valid_set's atec_metric: 0.496802
# [290]	valid_set's auc: 0.971119	valid_set's atec_metric: 0.496899
# [291]	valid_set's auc: 0.971123	valid_set's atec_metric: 0.496996
# [292]	valid_set's auc: 0.971117	valid_set's atec_metric: 0.495155
# [293]	valid_set's auc: 0.971131	valid_set's atec_metric: 0.496318
# [294]	valid_set's auc: 0.971145	valid_set's atec_metric: 0.499322
# [295]	valid_set's auc: 0.971152	valid_set's atec_metric: 0.497578
# [296]	valid_set's auc: 0.971146	valid_set's atec_metric: 0.498353
# [297]	valid_set's auc: 0.971149	valid_set's atec_metric: 0.498159
# [298]	valid_set's auc: 0.971184	valid_set's atec_metric: 0.498353
# [299]	valid_set's auc: 0.971203	valid_set's atec_metric: 0.495833
# [300]	valid_set's auc: 0.971282	valid_set's atec_metric: 0.498547
# [301]	valid_set's auc: 0.971337	valid_set's atec_metric: 0.497578
# [302]	valid_set's auc: 0.971376	valid_set's atec_metric: 0.496996
# [303]	valid_set's auc: 0.971437	valid_set's atec_metric: 0.497674
# [304]	valid_set's auc: 0.971619	valid_set's atec_metric: 0.498353
# [305]	valid_set's auc: 0.971678	valid_set's atec_metric: 0.499903
# [306]	valid_set's auc: 0.971711	valid_set's atec_metric: 0.499322
# [307]	valid_set's auc: 0.971761	valid_set's atec_metric: 0.499031
# [308]	valid_set's auc: 0.971758	valid_set's atec_metric: 0.499709
# [309]	valid_set's auc: 0.971775	valid_set's atec_metric: 0.500969
# [310]	valid_set's auc: 0.971806	valid_set's atec_metric: 0.500872
# [311]	valid_set's auc: 0.971792	valid_set's atec_metric: 0.499903
# [312]	valid_set's auc: 0.971813	valid_set's atec_metric: 0.50126
# [313]	valid_set's auc: 0.971807	valid_set's atec_metric: 0.500775
# [314]	valid_set's auc: 0.971994	valid_set's atec_metric: 0.50126
# [315]	valid_set's auc: 0.972036	valid_set's atec_metric: 0.501066
# [316]	valid_set's auc: 0.972042	valid_set's atec_metric: 0.50281
# [317]	valid_set's auc: 0.972098	valid_set's atec_metric: 0.504167
# [318]	valid_set's auc: 0.972114	valid_set's atec_metric: 0.503779
# [319]	valid_set's auc: 0.97209	valid_set's atec_metric: 0.504457
# [320]	valid_set's auc: 0.972116	valid_set's atec_metric: 0.504748
# [321]	valid_set's auc: 0.97216	valid_set's atec_metric: 0.505136
# [322]	valid_set's auc: 0.972195	valid_set's atec_metric: 0.504748
# [323]	valid_set's auc: 0.972389	valid_set's atec_metric: 0.505717
# [324]	valid_set's auc: 0.97241	valid_set's atec_metric: 0.505329
# [325]	valid_set's auc: 0.972412	valid_set's atec_metric: 0.506008
# [326]	valid_set's auc: 0.972465	valid_set's atec_metric: 0.506008
# [327]	valid_set's auc: 0.972563	valid_set's atec_metric: 0.505426
# [328]	valid_set's auc: 0.972639	valid_set's atec_metric: 0.505523
# [329]	valid_set's auc: 0.972707	valid_set's atec_metric: 0.506105
# [330]	valid_set's auc: 0.972762	valid_set's atec_metric: 0.506395
# [331]	valid_set's auc: 0.972766	valid_set's atec_metric: 0.506783
# [332]	valid_set's auc: 0.972786	valid_set's atec_metric: 0.507946
# [333]	valid_set's auc: 0.972928	valid_set's atec_metric: 0.507655
# [334]	valid_set's auc: 0.972982	valid_set's atec_metric: 0.509109
# [335]	valid_set's auc: 0.973034	valid_set's atec_metric: 0.508236
# [336]	valid_set's auc: 0.973088	valid_set's atec_metric: 0.509496
# [337]	valid_set's auc: 0.973134	valid_set's atec_metric: 0.508818
# [338]	valid_set's auc: 0.973149	valid_set's atec_metric: 0.509593
# [339]	valid_set's auc: 0.973188	valid_set's atec_metric: 0.509496
# [340]	valid_set's auc: 0.973193	valid_set's atec_metric: 0.510562
# [341]	valid_set's auc: 0.973223	valid_set's atec_metric: 0.510271
# [342]	valid_set's auc: 0.973326	valid_set's atec_metric: 0.50969
# [343]	valid_set's auc: 0.973358	valid_set's atec_metric: 0.509981
# [344]	valid_set's auc: 0.973419	valid_set's atec_metric: 0.512016
# [345]	valid_set's auc: 0.973428	valid_set's atec_metric: 0.511822
# [346]	valid_set's auc: 0.973458	valid_set's atec_metric: 0.511434
# [347]	valid_set's auc: 0.973472	valid_set's atec_metric: 0.511531
# [348]	valid_set's auc: 0.973516	valid_set's atec_metric: 0.511919
# [349]	valid_set's auc: 0.973536	valid_set's atec_metric: 0.511143
# [350]	valid_set's auc: 0.973537	valid_set's atec_metric: 0.511047
# [351]	valid_set's auc: 0.973569	valid_set's atec_metric: 0.512403
# [352]	valid_set's auc: 0.973589	valid_set's atec_metric: 0.510078
# [353]	valid_set's auc: 0.973607	valid_set's atec_metric: 0.511434
# [354]	valid_set's auc: 0.973581	valid_set's atec_metric: 0.5125
# [355]	valid_set's auc: 0.973598	valid_set's atec_metric: 0.511822
# [356]	valid_set's auc: 0.973596	valid_set's atec_metric: 0.513081
# [357]	valid_set's auc: 0.97367	valid_set's atec_metric: 0.515988
# [358]	valid_set's auc: 0.97367	valid_set's atec_metric: 0.514341
# [359]	valid_set's auc: 0.973681	valid_set's atec_metric: 0.514147
# [360]	valid_set's auc: 0.973752	valid_set's atec_metric: 0.513469
# [361]	valid_set's auc: 0.973904	valid_set's atec_metric: 0.513857
# [362]	valid_set's auc: 0.973994	valid_set's atec_metric: 0.514826
# [363]	valid_set's auc: 0.974057	valid_set's atec_metric: 0.514632
# [364]	valid_set's auc: 0.974131	valid_set's atec_metric: 0.515019
# [365]	valid_set's auc: 0.974153	valid_set's atec_metric: 0.514632
# [366]	valid_set's auc: 0.974164	valid_set's atec_metric: 0.514632
# [367]	valid_set's auc: 0.974178	valid_set's atec_metric: 0.515116
# [368]	valid_set's auc: 0.97425	valid_set's atec_metric: 0.514535
# [369]	valid_set's auc: 0.974107	valid_set's atec_metric: 0.514244
# [370]	valid_set's auc: 0.97431	valid_set's atec_metric: 0.514147
# [371]	valid_set's auc: 0.974315	valid_set's atec_metric: 0.512984
# [372]	valid_set's auc: 0.97434	valid_set's atec_metric: 0.513081
# [373]	valid_set's auc: 0.974341	valid_set's atec_metric: 0.514244
# [374]	valid_set's auc: 0.974337	valid_set's atec_metric: 0.514147
# [375]	valid_set's auc: 0.97433	valid_set's atec_metric: 0.512306
# [376]	valid_set's auc: 0.974335	valid_set's atec_metric: 0.511531
# [377]	valid_set's auc: 0.97436	valid_set's atec_metric: 0.510562
# [378]	valid_set's auc: 0.974362	valid_set's atec_metric: 0.511531
# [379]	valid_set's auc: 0.974404	valid_set's atec_metric: 0.511434
# [380]	valid_set's auc: 0.974422	valid_set's atec_metric: 0.510853
# [381]	valid_set's auc: 0.974447	valid_set's atec_metric: 0.510756
# [382]	valid_set's auc: 0.974465	valid_set's atec_metric: 0.511725
# [383]	valid_set's auc: 0.974493	valid_set's atec_metric: 0.510562
# [384]	valid_set's auc: 0.974495	valid_set's atec_metric: 0.510465
# [385]	valid_set's auc: 0.974514	valid_set's atec_metric: 0.510368
# [386]	valid_set's auc: 0.974862	valid_set's atec_metric: 0.512209
# [387]	valid_set's auc: 0.974938	valid_set's atec_metric: 0.511822
# [388]	valid_set's auc: 0.975085	valid_set's atec_metric: 0.512984
# [389]	valid_set's auc: 0.975279	valid_set's atec_metric: 0.513081
# [390]	valid_set's auc: 0.975687	valid_set's atec_metric: 0.515019
# [391]	valid_set's auc: 0.975711	valid_set's atec_metric: 0.514244
# [392]	valid_set's auc: 0.975826	valid_set's atec_metric: 0.514535
# [393]	valid_set's auc: 0.975836	valid_set's atec_metric: 0.514244
# [394]	valid_set's auc: 0.97588	valid_set's atec_metric: 0.514826
# [395]	valid_set's auc: 0.975907	valid_set's atec_metric: 0.515601
# [396]	valid_set's auc: 0.975899	valid_set's atec_metric: 0.516279
# [397]	valid_set's auc: 0.975908	valid_set's atec_metric: 0.516764
# [398]	valid_set's auc: 0.975844	valid_set's atec_metric: 0.515988
# [399]	valid_set's auc: 0.975828	valid_set's atec_metric: 0.514826
# [400]	valid_set's auc: 0.975838	valid_set's atec_metric: 0.514826
# [401]	valid_set's auc: 0.975855	valid_set's atec_metric: 0.514438
# [402]	valid_set's auc: 0.975863	valid_set's atec_metric: 0.514535
# [403]	valid_set's auc: 0.975889	valid_set's atec_metric: 0.514244
# [404]	valid_set's auc: 0.975884	valid_set's atec_metric: 0.514535
# [405]	valid_set's auc: 0.975814	valid_set's atec_metric: 0.514341
# [406]	valid_set's auc: 0.975872	valid_set's atec_metric: 0.514341
# [407]	valid_set's auc: 0.975921	valid_set's atec_metric: 0.512888
# [408]	valid_set's auc: 0.976135	valid_set's atec_metric: 0.512694
# [409]	valid_set's auc: 0.976161	valid_set's atec_metric: 0.512984
# [410]	valid_set's auc: 0.976239	valid_set's atec_metric: 0.51376
# [411]	valid_set's auc: 0.976245	valid_set's atec_metric: 0.514147
# [412]	valid_set's auc: 0.976287	valid_set's atec_metric: 0.51405
# [413]	valid_set's auc: 0.976523	valid_set's atec_metric: 0.513857
# [414]	valid_set's auc: 0.976585	valid_set's atec_metric: 0.514729
# [415]	valid_set's auc: 0.97673	valid_set's atec_metric: 0.513953
# [416]	valid_set's auc: 0.976755	valid_set's atec_metric: 0.514729
# [417]	valid_set's auc: 0.976762	valid_set's atec_metric: 0.517151
# [418]	valid_set's auc: 0.976869	valid_set's atec_metric: 0.517829
# [419]	valid_set's auc: 0.976907	valid_set's atec_metric: 0.518217
# [420]	valid_set's auc: 0.976926	valid_set's atec_metric: 0.51657
# [421]	valid_set's auc: 0.976958	valid_set's atec_metric: 0.51812
# [422]	valid_set's auc: 0.976995	valid_set's atec_metric: 0.516957
# [423]	valid_set's auc: 0.977035	valid_set's atec_metric: 0.51812
# [424]	valid_set's auc: 0.977063	valid_set's atec_metric: 0.518508
# [425]	valid_set's auc: 0.977092	valid_set's atec_metric: 0.517733
# [426]	valid_set's auc: 0.977121	valid_set's atec_metric: 0.515795
# [427]	valid_set's auc: 0.977131	valid_set's atec_metric: 0.514729
# [428]	valid_set's auc: 0.977179	valid_set's atec_metric: 0.514922
# [429]	valid_set's auc: 0.977212	valid_set's atec_metric: 0.513469
# [430]	valid_set's auc: 0.977251	valid_set's atec_metric: 0.514147
# [431]	valid_set's auc: 0.977269	valid_set's atec_metric: 0.514535
# [432]	valid_set's auc: 0.977317	valid_set's atec_metric: 0.515213
# [433]	valid_set's auc: 0.977338	valid_set's atec_metric: 0.515504
# [434]	valid_set's auc: 0.977355	valid_set's atec_metric: 0.515891
# [435]	valid_set's auc: 0.977386	valid_set's atec_metric: 0.516473
# [436]	valid_set's auc: 0.97741	valid_set's atec_metric: 0.51657
# [437]	valid_set's auc: 0.977438	valid_set's atec_metric: 0.515988
# [438]	valid_set's auc: 0.977451	valid_set's atec_metric: 0.515795
# [439]	valid_set's auc: 0.977466	valid_set's atec_metric: 0.51657
# [440]	valid_set's auc: 0.977462	valid_set's atec_metric: 0.516957
# [441]	valid_set's auc: 0.977482	valid_set's atec_metric: 0.516279
# [442]	valid_set's auc: 0.977503	valid_set's atec_metric: 0.515116
# [443]	valid_set's auc: 0.977508	valid_set's atec_metric: 0.51531
# [444]	valid_set's auc: 0.977553	valid_set's atec_metric: 0.515407
# [445]	valid_set's auc: 0.977582	valid_set's atec_metric: 0.515698
# [446]	valid_set's auc: 0.977733	valid_set's atec_metric: 0.515019
# [447]	valid_set's auc: 0.977723	valid_set's atec_metric: 0.515698
# [448]	valid_set's auc: 0.977749	valid_set's atec_metric: 0.513663
# [449]	valid_set's auc: 0.977786	valid_set's atec_metric: 0.514535
# [450]	valid_set's auc: 0.977804	valid_set's atec_metric: 0.513663
# [451]	valid_set's auc: 0.97782	valid_set's atec_metric: 0.51405
# [452]	valid_set's auc: 0.977803	valid_set's atec_metric: 0.51376
# [453]	valid_set's auc: 0.977806	valid_set's atec_metric: 0.512791
# [454]	valid_set's auc: 0.977794	valid_set's atec_metric: 0.513372
# [455]	valid_set's auc: 0.977801	valid_set's atec_metric: 0.512597
# [456]	valid_set's auc: 0.977823	valid_set's atec_metric: 0.514438
# [457]	valid_set's auc: 0.977824	valid_set's atec_metric: 0.513566
# [458]	valid_set's auc: 0.977872	valid_set's atec_metric: 0.514729
# [459]	valid_set's auc: 0.977864	valid_set's atec_metric: 0.515019
# [460]	valid_set's auc: 0.977873	valid_set's atec_metric: 0.514632
# [461]	valid_set's auc: 0.977914	valid_set's atec_metric: 0.514729
# [462]	valid_set's auc: 0.977943	valid_set's atec_metric: 0.514341
# [463]	valid_set's auc: 0.977977	valid_set's atec_metric: 0.51531
# [464]	valid_set's auc: 0.978022	valid_set's atec_metric: 0.515407
# [465]	valid_set's auc: 0.978039	valid_set's atec_metric: 0.515795
# [466]	valid_set's auc: 0.978069	valid_set's atec_metric: 0.515407
# [467]	valid_set's auc: 0.978099	valid_set's atec_metric: 0.513857
# [468]	valid_set's auc: 0.978186	valid_set's atec_metric: 0.512888
# [469]	valid_set's auc: 0.978246	valid_set's atec_metric: 0.512112
# [470]	valid_set's auc: 0.97825	valid_set's atec_metric: 0.513566
# [471]	valid_set's auc: 0.97828	valid_set's atec_metric: 0.513081
# [472]	valid_set's auc: 0.978325	valid_set's atec_metric: 0.513372
# [473]	valid_set's auc: 0.978392	valid_set's atec_metric: 0.51405
# [474]	valid_set's auc: 0.9784	valid_set's atec_metric: 0.513372
# [475]	valid_set's auc: 0.978442	valid_set's atec_metric: 0.513953
# [476]	valid_set's auc: 0.978457	valid_set's atec_metric: 0.513275
# [477]	valid_set's auc: 0.978488	valid_set's atec_metric: 0.512597
# [478]	valid_set's auc: 0.978487	valid_set's atec_metric: 0.512694
# [479]	valid_set's auc: 0.978581	valid_set's atec_metric: 0.512694
# [480]	valid_set's auc: 0.978616	valid_set's atec_metric: 0.512016
# [481]	valid_set's auc: 0.978624	valid_set's atec_metric: 0.512984
# [482]	valid_set's auc: 0.978642	valid_set's atec_metric: 0.513663
# [483]	valid_set's auc: 0.978658	valid_set's atec_metric: 0.514438
# [484]	valid_set's auc: 0.978672	valid_set's atec_metric: 0.51376
# [485]	valid_set's auc: 0.978697	valid_set's atec_metric: 0.513857
# [486]	valid_set's auc: 0.978723	valid_set's atec_metric: 0.513953
# [487]	valid_set's auc: 0.978749	valid_set's atec_metric: 0.513178
# [488]	valid_set's auc: 0.978735	valid_set's atec_metric: 0.513566
# [489]	valid_set's auc: 0.97878	valid_set's atec_metric: 0.512403
# [490]	valid_set's auc: 0.978829	valid_set's atec_metric: 0.512791
# [491]	valid_set's auc: 0.978875	valid_set's atec_metric: 0.512888
# [492]	valid_set's auc: 0.97891	valid_set's atec_metric: 0.511725
# [493]	valid_set's auc: 0.978939	valid_set's atec_metric: 0.510659
# [494]	valid_set's auc: 0.978979	valid_set's atec_metric: 0.51095
# [495]	valid_set's auc: 0.979008	valid_set's atec_metric: 0.509981
# [496]	valid_set's auc: 0.979027	valid_set's atec_metric: 0.509884
# [497]	valid_set's auc: 0.97904	valid_set's atec_metric: 0.509496
# [498]	valid_set's auc: 0.979123	valid_set's atec_metric: 0.509593
# [499]	valid_set's auc: 0.979133	valid_set's atec_metric: 0.508721
# [500]	valid_set's auc: 0.979135	valid_set's atec_metric: 0.50969
# [501]	valid_set's auc: 0.97918	valid_set's atec_metric: 0.509012
# [502]	valid_set's auc: 0.979203	valid_set's atec_metric: 0.511143
# [503]	valid_set's auc: 0.97923	valid_set's atec_metric: 0.510853
# [504]	valid_set's auc: 0.979242	valid_set's atec_metric: 0.510562
# [505]	valid_set's auc: 0.979258	valid_set's atec_metric: 0.510174
# [506]	valid_set's auc: 0.979266	valid_set's atec_metric: 0.510174
# [507]	valid_set's auc: 0.97929	valid_set's atec_metric: 0.510853
# [508]	valid_set's auc: 0.979293	valid_set's atec_metric: 0.509302
# [509]	valid_set's auc: 0.979313	valid_set's atec_metric: 0.509109
# [510]	valid_set's auc: 0.979309	valid_set's atec_metric: 0.509012
# [511]	valid_set's auc: 0.979305	valid_set's atec_metric: 0.508721
# [512]	valid_set's auc: 0.979332	valid_set's atec_metric: 0.509012
# [513]	valid_set's auc: 0.979369	valid_set's atec_metric: 0.509399
# [514]	valid_set's auc: 0.979378	valid_set's atec_metric: 0.509787
# [515]	valid_set's auc: 0.979363	valid_set's atec_metric: 0.508721
# [516]	valid_set's auc: 0.97942	valid_set's atec_metric: 0.509787
# [517]	valid_set's auc: 0.979451	valid_set's atec_metric: 0.508624
# [518]	valid_set's auc: 0.979457	valid_set's atec_metric: 0.510562
# [519]	valid_set's auc: 0.979456	valid_set's atec_metric: 0.509302
# [520]	valid_set's auc: 0.979493	valid_set's atec_metric: 0.510853
# [521]	valid_set's auc: 0.979525	valid_set's atec_metric: 0.510368
# [522]	valid_set's auc: 0.979548	valid_set's atec_metric: 0.511822
# [523]	valid_set's auc: 0.979569	valid_set's atec_metric: 0.509399
# [524]	valid_set's auc: 0.979592	valid_set's atec_metric: 0.509787
# Early stopping, best iteration is:
# [424]	valid_set's auc: 0.977063	valid_set's atec_metric: 0.518508
