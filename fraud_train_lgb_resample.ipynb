# %%
# %matplotlib inline
import pandas as pd
import lightgbm as lgb
import numpy as np
import os
from __future__ import division
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.model_selection import ParameterGrid
from imblearn.over_sampling import RandomOverSampler
import datetime
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
df_train=pd.read_csv('data/atec_anti_fraud_train.csv', parse_dates=['date'])

# %%
df_train_clean=df_train.loc[df_train['label']!=-1]
del df_train

# %%
y=df_train_clean['label']
X=df_train_clean.drop(['id','label','date'],axis=1)
cut_date_train=datetime.datetime(2017,10,20)
cut_date_test=datetime.datetime(2017,11,1)

# %%
x_train=X[df_train_clean.date<=cut_date_train].values
x_test=X[df_train_clean.date>=cut_date_test].values
y_train=y[df_train_clean.date<=cut_date_train].values
y_test=y[df_train_clean.date>=cut_date_test].values

# %%
num_values=2000
category_feature=[]
for i in range(X.shape[1]):
    num = X['f'+str(i+1)].unique().shape[0]
    if num <=num_values:
        category_feature.append(i)

# %%
del df_train_clean, X, y

# %%
def atec_metric(preds, train_data):
    labels = train_data.get_label()
    fpr,tpr,threshhold=roc_curve(labels, preds)
    return 'atec_metric', 0.4*tpr[fpr<=0.001][-1] + 0.3*tpr[fpr<=0.005][-1] + 0.3*tpr[fpr<=0.01][-1], True

# %%
num_0=sum(y_train==0)
res=RandomOverSampler({0:num_0,1:int(num_0*0.1)})
x_resample,y_resample=res.fit_sample(x_train,y_train)

# %%
feature_name=['feasture_'+str(col+1) for col in range(x_train.shape[1])]
#W_weight=9*(1-y_train)+1
lgb_train=lgb.Dataset(x_resample,y_resample,free_raw_data=False,feature_name=feature_name, categorical_feature=category_feature)
lgb_valid=lgb.Dataset(x_test,y_test,reference=lgb_train,free_raw_data=False,feature_name=feature_name, categorical_feature=category_feature)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'device': 'cpu',
    'verbose': 0,
    'early_stopping_round': 100,
    'learning_rate': 0.01,
    'num_leaves': 128,
    'lambda_l1': 0.006,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': [5],
    'bagging_seed':3,
    'feature_fration_seed':2
}

# %%
gbm = lgb.train(params, lgb_train, num_boost_round=10000, valid_sets=[lgb_train,lgb_valid], valid_names=['train_set','valid_set'],feval=atec_metric)
# Out:
# C:\Users\Dong\Anaconda3\lib\site-packages\lightgbm\engine.py:104: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# C:\Users\Dong\Anaconda3\lib\site-packages\lightgbm\basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# C:\Users\Dong\Anaconda3\lib\site-packages\lightgbm\basic.py:681: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [1]	train_set's auc: 0.972747	train_set's atec_metric: 0.394136	valid_set's auc: 0.960088	valid_set's atec_metric: 0.288178
# Training until validation scores don't improve for 100 rounds.
# [2]	train_set's auc: 0.979482	train_set's atec_metric: 0.434658	valid_set's auc: 0.968686	valid_set's atec_metric: 0.356202
# [3]	train_set's auc: 0.980176	train_set's atec_metric: 0.435913	valid_set's auc: 0.969742	valid_set's atec_metric: 0.352713
# [4]	train_set's auc: 0.980136	train_set's atec_metric: 0.436632	valid_set's auc: 0.969849	valid_set's atec_metric: 0.351453
# [5]	train_set's auc: 0.980012	train_set's atec_metric: 0.437091	valid_set's auc: 0.969615	valid_set's atec_metric: 0.353779
# [6]	train_set's auc: 0.980676	train_set's atec_metric: 0.514063	valid_set's auc: 0.970323	valid_set's atec_metric: 0.375
# [7]	train_set's auc: 0.98154	train_set's atec_metric: 0.52137	valid_set's auc: 0.970428	valid_set's atec_metric: 0.372965
# [8]	train_set's auc: 0.981726	train_set's atec_metric: 0.524822	valid_set's auc: 0.970772	valid_set's atec_metric: 0.373547
# [9]	train_set's auc: 0.981899	train_set's atec_metric: 0.52513	valid_set's auc: 0.970804	valid_set's atec_metric: 0.371802
# [10]	train_set's auc: 0.983187	train_set's atec_metric: 0.525273	valid_set's auc: 0.971624	valid_set's atec_metric: 0.372384
# [11]	train_set's auc: 0.983204	train_set's atec_metric: 0.526863	valid_set's auc: 0.971692	valid_set's atec_metric: 0.370058
# [12]	train_set's auc: 0.983185	train_set's atec_metric: 0.527287	valid_set's auc: 0.971628	valid_set's atec_metric: 0.373547
# [13]	train_set's auc: 0.983271	train_set's atec_metric: 0.526245	valid_set's auc: 0.971607	valid_set's atec_metric: 0.373256
# [14]	train_set's auc: 0.983191	train_set's atec_metric: 0.529372	valid_set's auc: 0.971513	valid_set's atec_metric: 0.374419
# [15]	train_set's auc: 0.983139	train_set's atec_metric: 0.528727	valid_set's auc: 0.971519	valid_set's atec_metric: 0.376453
# [16]	train_set's auc: 0.983258	train_set's atec_metric: 0.534122	valid_set's auc: 0.971658	valid_set's atec_metric: 0.378198
# [17]	train_set's auc: 0.983365	train_set's atec_metric: 0.532654	valid_set's auc: 0.971707	valid_set's atec_metric: 0.377035
# [18]	train_set's auc: 0.983549	train_set's atec_metric: 0.535507	valid_set's auc: 0.971185	valid_set's atec_metric: 0.37907
# [19]	train_set's auc: 0.983548	train_set's atec_metric: 0.53616	valid_set's auc: 0.971185	valid_set's atec_metric: 0.377326
# [20]	train_set's auc: 0.983607	train_set's atec_metric: 0.535561	valid_set's auc: 0.971207	valid_set's atec_metric: 0.375291
# [21]	train_set's auc: 0.983753	train_set's atec_metric: 0.53493	valid_set's auc: 0.971315	valid_set's atec_metric: 0.376744
# [22]	train_set's auc: 0.983835	train_set's atec_metric: 0.54403	valid_set's auc: 0.97127	valid_set's atec_metric: 0.376453
# [23]	train_set's auc: 0.983866	train_set's atec_metric: 0.54282	valid_set's auc: 0.971793	valid_set's atec_metric: 0.377035
# [24]	train_set's auc: 0.983898	train_set's atec_metric: 0.541975	valid_set's auc: 0.971796	valid_set's atec_metric: 0.376163
# [25]	train_set's auc: 0.983935	train_set's atec_metric: 0.543592	valid_set's auc: 0.971684	valid_set's atec_metric: 0.377326
# [26]	train_set's auc: 0.984949	train_set's atec_metric: 0.543058	valid_set's auc: 0.972646	valid_set's atec_metric: 0.376744
# [27]	train_set's auc: 0.985028	train_set's atec_metric: 0.546392	valid_set's auc: 0.972543	valid_set's atec_metric: 0.377035
# [28]	train_set's auc: 0.985331	train_set's atec_metric: 0.547063	valid_set's auc: 0.972881	valid_set's atec_metric: 0.37936
# [29]	train_set's auc: 0.985423	train_set's atec_metric: 0.547996	valid_set's auc: 0.972983	valid_set's atec_metric: 0.378779
# [30]	train_set's auc: 0.985575	train_set's atec_metric: 0.547552	valid_set's auc: 0.973236	valid_set's atec_metric: 0.378198
# [31]	train_set's auc: 0.985721	train_set's atec_metric: 0.549692	valid_set's auc: 0.973598	valid_set's atec_metric: 0.380523
# [32]	train_set's auc: 0.98571	train_set's atec_metric: 0.54856	valid_set's auc: 0.973605	valid_set's atec_metric: 0.380233
# [33]	train_set's auc: 0.985728	train_set's atec_metric: 0.54968	valid_set's auc: 0.973661	valid_set's atec_metric: 0.382267
# [34]	train_set's auc: 0.985788	train_set's atec_metric: 0.550386	valid_set's auc: 0.97364	valid_set's atec_metric: 0.382558
# [35]	train_set's auc: 0.985768	train_set's atec_metric: 0.553241	valid_set's auc: 0.973613	valid_set's atec_metric: 0.382849
# [36]	train_set's auc: 0.985762	train_set's atec_metric: 0.553486	valid_set's auc: 0.973699	valid_set's atec_metric: 0.38343
# [37]	train_set's auc: 0.985851	train_set's atec_metric: 0.553676	valid_set's auc: 0.973704	valid_set's atec_metric: 0.38343
# [38]	train_set's auc: 0.985874	train_set's atec_metric: 0.554397	valid_set's auc: 0.973695	valid_set's atec_metric: 0.384593
# [39]	train_set's auc: 0.985925	train_set's atec_metric: 0.556019	valid_set's auc: 0.973705	valid_set's atec_metric: 0.384884
# [40]	train_set's auc: 0.986175	train_set's atec_metric: 0.554709	valid_set's auc: 0.973656	valid_set's atec_metric: 0.386047
# [41]	train_set's auc: 0.986256	train_set's atec_metric: 0.557348	valid_set's auc: 0.973715	valid_set's atec_metric: 0.386337
# [42]	train_set's auc: 0.986282	train_set's atec_metric: 0.556608	valid_set's auc: 0.973705	valid_set's atec_metric: 0.387209
# [43]	train_set's auc: 0.986341	train_set's atec_metric: 0.55696	valid_set's auc: 0.973785	valid_set's atec_metric: 0.388663
# [44]	train_set's auc: 0.986366	train_set's atec_metric: 0.557454	valid_set's auc: 0.973763	valid_set's atec_metric: 0.387209
# [45]	train_set's auc: 0.986433	train_set's atec_metric: 0.561966	valid_set's auc: 0.973863	valid_set's atec_metric: 0.386919
# [46]	train_set's auc: 0.986492	train_set's atec_metric: 0.563492	valid_set's auc: 0.973938	valid_set's atec_metric: 0.386337
# [47]	train_set's auc: 0.986545	train_set's atec_metric: 0.560275	valid_set's auc: 0.973905	valid_set's atec_metric: 0.387209
# [48]	train_set's auc: 0.986567	train_set's atec_metric: 0.560541	valid_set's auc: 0.97404	valid_set's atec_metric: 0.386919
# [49]	train_set's auc: 0.986606	train_set's atec_metric: 0.560802	valid_set's auc: 0.97407	valid_set's atec_metric: 0.387209
# [50]	train_set's auc: 0.986709	train_set's atec_metric: 0.560318	valid_set's auc: 0.974175	valid_set's atec_metric: 0.385756
# [51]	train_set's auc: 0.986978	train_set's atec_metric: 0.564312	valid_set's auc: 0.974242	valid_set's atec_metric: 0.385465
# [52]	train_set's auc: 0.987017	train_set's atec_metric: 0.564468	valid_set's auc: 0.974412	valid_set's atec_metric: 0.385756
# [53]	train_set's auc: 0.987031	train_set's atec_metric: 0.565393	valid_set's auc: 0.97438	valid_set's atec_metric: 0.385174
# [54]	train_set's auc: 0.987032	train_set's atec_metric: 0.565961	valid_set's auc: 0.974398	valid_set's atec_metric: 0.384593
# [55]	train_set's auc: 0.987087	train_set's atec_metric: 0.566947	valid_set's auc: 0.974396	valid_set's atec_metric: 0.384302
# [56]	train_set's auc: 0.987205	train_set's atec_metric: 0.567039	valid_set's auc: 0.974502	valid_set's atec_metric: 0.384884
# [57]	train_set's auc: 0.987243	train_set's atec_metric: 0.568199	valid_set's auc: 0.974563	valid_set's atec_metric: 0.384884
# [58]	train_set's auc: 0.987255	train_set's atec_metric: 0.569181	valid_set's auc: 0.974602	valid_set's atec_metric: 0.384012
# [59]	train_set's auc: 0.987321	train_set's atec_metric: 0.5706	valid_set's auc: 0.97459	valid_set's atec_metric: 0.446705
# [60]	train_set's auc: 0.987384	train_set's atec_metric: 0.570762	valid_set's auc: 0.974645	valid_set's atec_metric: 0.450484
# [61]	train_set's auc: 0.987407	train_set's atec_metric: 0.571844	valid_set's auc: 0.974689	valid_set's atec_metric: 0.450484
# [62]	train_set's auc: 0.987452	train_set's atec_metric: 0.573366	valid_set's auc: 0.974698	valid_set's atec_metric: 0.451647
# [63]	train_set's auc: 0.987468	train_set's atec_metric: 0.573732	valid_set's auc: 0.974738	valid_set's atec_metric: 0.451066
# [64]	train_set's auc: 0.987494	train_set's atec_metric: 0.573625	valid_set's auc: 0.974765	valid_set's atec_metric: 0.450775
# [65]	train_set's auc: 0.987535	train_set's atec_metric: 0.573607	valid_set's auc: 0.974803	valid_set's atec_metric: 0.450194
# [66]	train_set's auc: 0.987566	train_set's atec_metric: 0.573638	valid_set's auc: 0.97461	valid_set's atec_metric: 0.450194
# [67]	train_set's auc: 0.987597	train_set's atec_metric: 0.574117	valid_set's auc: 0.973487	valid_set's atec_metric: 0.449322
# [68]	train_set's auc: 0.987621	train_set's atec_metric: 0.577374	valid_set's auc: 0.973492	valid_set's atec_metric: 0.455426
# [69]	train_set's auc: 0.987655	train_set's atec_metric: 0.578072	valid_set's auc: 0.973602	valid_set's atec_metric: 0.456008
# [70]	train_set's auc: 0.987679	train_set's atec_metric: 0.580212	valid_set's auc: 0.973617	valid_set's atec_metric: 0.459205
# [71]	train_set's auc: 0.987711	train_set's atec_metric: 0.582304	valid_set's auc: 0.973709	valid_set's atec_metric: 0.456492
# [72]	train_set's auc: 0.987739	train_set's atec_metric: 0.583794	valid_set's auc: 0.97382	valid_set's atec_metric: 0.46095
# [73]	train_set's auc: 0.987764	train_set's atec_metric: 0.584226	valid_set's auc: 0.97393	valid_set's atec_metric: 0.459593
# [74]	train_set's auc: 0.987792	train_set's atec_metric: 0.586198	valid_set's auc: 0.973953	valid_set's atec_metric: 0.462694
# [75]	train_set's auc: 0.987809	train_set's atec_metric: 0.586919	valid_set's auc: 0.974436	valid_set's atec_metric: 0.46531
# [76]	train_set's auc: 0.987847	train_set's atec_metric: 0.587201	valid_set's auc: 0.974467	valid_set's atec_metric: 0.469574
# [77]	train_set's auc: 0.987866	train_set's atec_metric: 0.588469	valid_set's auc: 0.974557	valid_set's atec_metric: 0.469961
# [78]	train_set's auc: 0.987913	train_set's atec_metric: 0.588066	valid_set's auc: 0.974598	valid_set's atec_metric: 0.469961
# [79]	train_set's auc: 0.987938	train_set's atec_metric: 0.589145	valid_set's auc: 0.974648	valid_set's atec_metric: 0.472384
# [80]	train_set's auc: 0.987963	train_set's atec_metric: 0.590318	valid_set's auc: 0.974899	valid_set's atec_metric: 0.475291
# [81]	train_set's auc: 0.988017	train_set's atec_metric: 0.590506	valid_set's auc: 0.97499	valid_set's atec_metric: 0.475484
# [82]	train_set's auc: 0.988127	train_set's atec_metric: 0.593021	valid_set's auc: 0.975015	valid_set's atec_metric: 0.476357
# [83]	train_set's auc: 0.988184	train_set's atec_metric: 0.594362	valid_set's auc: 0.974993	valid_set's atec_metric: 0.47626
# [84]	train_set's auc: 0.988218	train_set's atec_metric: 0.595213	valid_set's auc: 0.975044	valid_set's atec_metric: 0.476163
# [85]	train_set's auc: 0.988246	train_set's atec_metric: 0.596419	valid_set's auc: 0.975032	valid_set's atec_metric: 0.479651
# [86]	train_set's auc: 0.988278	train_set's atec_metric: 0.596702	valid_set's auc: 0.975033	valid_set's atec_metric: 0.480523
# [87]	train_set's auc: 0.988298	train_set's atec_metric: 0.597599	valid_set's auc: 0.975049	valid_set's atec_metric: 0.48062
# [88]	train_set's auc: 0.988359	train_set's atec_metric: 0.599584	valid_set's auc: 0.975031	valid_set's atec_metric: 0.478779
# [89]	train_set's auc: 0.988441	train_set's atec_metric: 0.600244	valid_set's auc: 0.975057	valid_set's atec_metric: 0.478198
# [90]	train_set's auc: 0.988519	train_set's atec_metric: 0.600157	valid_set's auc: 0.975097	valid_set's atec_metric: 0.478101
# [91]	train_set's auc: 0.988559	train_set's atec_metric: 0.601765	valid_set's auc: 0.975211	valid_set's atec_metric: 0.478198
# [92]	train_set's auc: 0.98859	train_set's atec_metric: 0.602601	valid_set's auc: 0.975188	valid_set's atec_metric: 0.476744
# [93]	train_set's auc: 0.988628	train_set's atec_metric: 0.602823	valid_set's auc: 0.975164	valid_set's atec_metric: 0.476066
# [94]	train_set's auc: 0.988689	train_set's atec_metric: 0.605917	valid_set's auc: 0.97514	valid_set's atec_metric: 0.475484
# [95]	train_set's auc: 0.988725	train_set's atec_metric: 0.606925	valid_set's auc: 0.975167	valid_set's atec_metric: 0.478391
# [96]	train_set's auc: 0.989098	train_set's atec_metric: 0.606846	valid_set's auc: 0.975214	valid_set's atec_metric: 0.482461
# [97]	train_set's auc: 0.989141	train_set's atec_metric: 0.611211	valid_set's auc: 0.975213	valid_set's atec_metric: 0.479457
# [98]	train_set's auc: 0.989168	train_set's atec_metric: 0.611434	valid_set's auc: 0.975278	valid_set's atec_metric: 0.479748
# [99]	train_set's auc: 0.9892	train_set's atec_metric: 0.614239	valid_set's auc: 0.975299	valid_set's atec_metric: 0.479942
# [100]	train_set's auc: 0.989326	train_set's atec_metric: 0.614834	valid_set's auc: 0.975342	valid_set's atec_metric: 0.480329
# [101]	train_set's auc: 0.989423	train_set's atec_metric: 0.614683	valid_set's auc: 0.975367	valid_set's atec_metric: 0.479845
# [102]	train_set's auc: 0.989445	train_set's atec_metric: 0.615047	valid_set's auc: 0.975416	valid_set's atec_metric: 0.480426
# [103]	train_set's auc: 0.9895	train_set's atec_metric: 0.615361	valid_set's auc: 0.975455	valid_set's atec_metric: 0.480717
# [104]	train_set's auc: 0.989555	train_set's atec_metric: 0.615568	valid_set's auc: 0.975546	valid_set's atec_metric: 0.480233
# [105]	train_set's auc: 0.989572	train_set's atec_metric: 0.615266	valid_set's auc: 0.975557	valid_set's atec_metric: 0.480911
# [106]	train_set's auc: 0.989585	train_set's atec_metric: 0.615876	valid_set's auc: 0.975571	valid_set's atec_metric: 0.480717
# [107]	train_set's auc: 0.98961	train_set's atec_metric: 0.618498	valid_set's auc: 0.975581	valid_set's atec_metric: 0.480717
# [108]	train_set's auc: 0.98962	train_set's atec_metric: 0.619719	valid_set's auc: 0.975609	valid_set's atec_metric: 0.47907
# [109]	train_set's auc: 0.989645	train_set's atec_metric: 0.62017	valid_set's auc: 0.975647	valid_set's atec_metric: 0.47936
# [110]	train_set's auc: 0.989656	train_set's atec_metric: 0.621215	valid_set's auc: 0.975616	valid_set's atec_metric: 0.479457
# [111]	train_set's auc: 0.98975	train_set's atec_metric: 0.622679	valid_set's auc: 0.975691	valid_set's atec_metric: 0.479457
# [112]	train_set's auc: 0.98982	train_set's atec_metric: 0.623588	valid_set's auc: 0.975733	valid_set's atec_metric: 0.479554
# [113]	train_set's auc: 0.98985	train_set's atec_metric: 0.624849	valid_set's auc: 0.975796	valid_set's atec_metric: 0.478876
# [114]	train_set's auc: 0.98992	train_set's atec_metric: 0.626034	valid_set's auc: 0.975805	valid_set's atec_metric: 0.477229
# [115]	train_set's auc: 0.989982	train_set's atec_metric: 0.625851	valid_set's auc: 0.975818	valid_set's atec_metric: 0.476841
# [116]	train_set's auc: 0.990027	train_set's atec_metric: 0.626426	valid_set's auc: 0.975939	valid_set's atec_metric: 0.475775
# [117]	train_set's auc: 0.99006	train_set's atec_metric: 0.627386	valid_set's auc: 0.976025	valid_set's atec_metric: 0.475097
# [118]	train_set's auc: 0.99011	train_set's atec_metric: 0.628694	valid_set's auc: 0.976022	valid_set's atec_metric: 0.474903
# [119]	train_set's auc: 0.990252	train_set's atec_metric: 0.630137	valid_set's auc: 0.976083	valid_set's atec_metric: 0.475291
# [120]	train_set's auc: 0.990298	train_set's atec_metric: 0.630463	valid_set's auc: 0.976123	valid_set's atec_metric: 0.473837
# [121]	train_set's auc: 0.990317	train_set's atec_metric: 0.631359	valid_set's auc: 0.976113	valid_set's atec_metric: 0.473837
# [122]	train_set's auc: 0.990357	train_set's atec_metric: 0.631259	valid_set's auc: 0.976207	valid_set's atec_metric: 0.474903
# [123]	train_set's auc: 0.990377	train_set's atec_metric: 0.631837	valid_set's auc: 0.976227	valid_set's atec_metric: 0.474709
# [124]	train_set's auc: 0.990416	train_set's atec_metric: 0.633093	valid_set's auc: 0.976292	valid_set's atec_metric: 0.475775
# [125]	train_set's auc: 0.990446	train_set's atec_metric: 0.632767	valid_set's auc: 0.976386	valid_set's atec_metric: 0.476066
# [126]	train_set's auc: 0.990466	train_set's atec_metric: 0.634231	valid_set's auc: 0.97642	valid_set's atec_metric: 0.474709
# [127]	train_set's auc: 0.990487	train_set's atec_metric: 0.635512	valid_set's auc: 0.976438	valid_set's atec_metric: 0.47781
# [128]	train_set's auc: 0.990504	train_set's atec_metric: 0.635645	valid_set's auc: 0.976477	valid_set's atec_metric: 0.477229
# [129]	train_set's auc: 0.990519	train_set's atec_metric: 0.6369	valid_set's auc: 0.976475	valid_set's atec_metric: 0.477907
# [130]	train_set's auc: 0.990544	train_set's atec_metric: 0.638106	valid_set's auc: 0.976469	valid_set's atec_metric: 0.477229
# [131]	train_set's auc: 0.990584	train_set's atec_metric: 0.638501	valid_set's auc: 0.976523	valid_set's atec_metric: 0.474516
# [132]	train_set's auc: 0.990608	train_set's atec_metric: 0.638584	valid_set's auc: 0.976598	valid_set's atec_metric: 0.475484
# [133]	train_set's auc: 0.990636	train_set's atec_metric: 0.638588	valid_set's auc: 0.976619	valid_set's atec_metric: 0.475581
# [134]	train_set's auc: 0.990676	train_set's atec_metric: 0.639175	valid_set's auc: 0.976654	valid_set's atec_metric: 0.47626
# [135]	train_set's auc: 0.990702	train_set's atec_metric: 0.640174	valid_set's auc: 0.97671	valid_set's atec_metric: 0.475775
# [136]	train_set's auc: 0.990756	train_set's atec_metric: 0.640319	valid_set's auc: 0.976515	valid_set's atec_metric: 0.473837
# [137]	train_set's auc: 0.990802	train_set's atec_metric: 0.642204	valid_set's auc: 0.97656	valid_set's atec_metric: 0.478004
# [138]	train_set's auc: 0.990834	train_set's atec_metric: 0.643952	valid_set's auc: 0.976568	valid_set's atec_metric: 0.477422
# [139]	train_set's auc: 0.99086	train_set's atec_metric: 0.644832	valid_set's auc: 0.976599	valid_set's atec_metric: 0.475097
# [140]	train_set's auc: 0.99089	train_set's atec_metric: 0.646406	valid_set's auc: 0.97667	valid_set's atec_metric: 0.473159
# [141]	train_set's auc: 0.99092	train_set's atec_metric: 0.648345	valid_set's auc: 0.97669	valid_set's atec_metric: 0.476163
# [142]	train_set's auc: 0.990943	train_set's atec_metric: 0.648878	valid_set's auc: 0.976691	valid_set's atec_metric: 0.475678
# [143]	train_set's auc: 0.990959	train_set's atec_metric: 0.650051	valid_set's auc: 0.976737	valid_set's atec_metric: 0.478973
# [144]	train_set's auc: 0.990994	train_set's atec_metric: 0.650447	valid_set's auc: 0.976696	valid_set's atec_metric: 0.479942
# [145]	train_set's auc: 0.991016	train_set's atec_metric: 0.65069	valid_set's auc: 0.976727	valid_set's atec_metric: 0.480523
# [146]	train_set's auc: 0.991034	train_set's atec_metric: 0.651032	valid_set's auc: 0.976747	valid_set's atec_metric: 0.482752
# [147]	train_set's auc: 0.991056	train_set's atec_metric: 0.652037	valid_set's auc: 0.976763	valid_set's atec_metric: 0.482074
# [148]	train_set's auc: 0.991076	train_set's atec_metric: 0.653171	valid_set's auc: 0.9768	valid_set's atec_metric: 0.479748
# [149]	train_set's auc: 0.991096	train_set's atec_metric: 0.654703	valid_set's auc: 0.97682	valid_set's atec_metric: 0.480329
# [150]	train_set's auc: 0.991121	train_set's atec_metric: 0.655764	valid_set's auc: 0.976858	valid_set's atec_metric: 0.485465
# [151]	train_set's auc: 0.991135	train_set's atec_metric: 0.65724	valid_set's auc: 0.976901	valid_set's atec_metric: 0.484302
# [152]	train_set's auc: 0.991152	train_set's atec_metric: 0.657662	valid_set's auc: 0.976915	valid_set's atec_metric: 0.484593
# [153]	train_set's auc: 0.991166	train_set's atec_metric: 0.658631	valid_set's auc: 0.976922	valid_set's atec_metric: 0.483818
# [154]	train_set's auc: 0.991206	train_set's atec_metric: 0.659119	valid_set's auc: 0.976913	valid_set's atec_metric: 0.483333
# [155]	train_set's auc: 0.991218	train_set's atec_metric: 0.660944	valid_set's auc: 0.976942	valid_set's atec_metric: 0.48188
# [156]	train_set's auc: 0.991259	train_set's atec_metric: 0.661392	valid_set's auc: 0.976958	valid_set's atec_metric: 0.484884
# [157]	train_set's auc: 0.991285	train_set's atec_metric: 0.661911	valid_set's auc: 0.976983	valid_set's atec_metric: 0.484787
# [158]	train_set's auc: 0.9913	train_set's atec_metric: 0.663082	valid_set's auc: 0.977073	valid_set's atec_metric: 0.486337
# [159]	train_set's auc: 0.991259	train_set's atec_metric: 0.663603	valid_set's auc: 0.977097	valid_set's atec_metric: 0.487016
# [160]	train_set's auc: 0.991287	train_set's atec_metric: 0.664406	valid_set's auc: 0.977137	valid_set's atec_metric: 0.488857
# [161]	train_set's auc: 0.991299	train_set's atec_metric: 0.664514	valid_set's auc: 0.977197	valid_set's atec_metric: 0.48905
# [162]	train_set's auc: 0.991314	train_set's atec_metric: 0.66511	valid_set's auc: 0.977301	valid_set's atec_metric: 0.489535
# [163]	train_set's auc: 0.991331	train_set's atec_metric: 0.665576	valid_set's auc: 0.977309	valid_set's atec_metric: 0.489147
# [164]	train_set's auc: 0.991343	train_set's atec_metric: 0.666585	valid_set's auc: 0.977348	valid_set's atec_metric: 0.488857
# [165]	train_set's auc: 0.991354	train_set's atec_metric: 0.667385	valid_set's auc: 0.977363	valid_set's atec_metric: 0.489826
# [166]	train_set's auc: 0.991448	train_set's atec_metric: 0.668959	valid_set's auc: 0.977436	valid_set's atec_metric: 0.488857
# [167]	train_set's auc: 0.991471	train_set's atec_metric: 0.669567	valid_set's auc: 0.977495	valid_set's atec_metric: 0.487791
# [168]	train_set's auc: 0.991494	train_set's atec_metric: 0.670319	valid_set's auc: 0.977491	valid_set's atec_metric: 0.487791
# [169]	train_set's auc: 0.991433	train_set's atec_metric: 0.672405	valid_set's auc: 0.977485	valid_set's atec_metric: 0.487791
# [170]	train_set's auc: 0.991452	train_set's atec_metric: 0.673595	valid_set's auc: 0.977487	valid_set's atec_metric: 0.490407
# [171]	train_set's auc: 0.991506	train_set's atec_metric: 0.67459	valid_set's auc: 0.97749	valid_set's atec_metric: 0.49031
# [172]	train_set's auc: 0.991525	train_set's atec_metric: 0.674881	valid_set's auc: 0.977507	valid_set's atec_metric: 0.489729
# [173]	train_set's auc: 0.991545	train_set's atec_metric: 0.675131	valid_set's auc: 0.977504	valid_set's atec_metric: 0.487791
# [174]	train_set's auc: 0.99156	train_set's atec_metric: 0.675954	valid_set's auc: 0.977506	valid_set's atec_metric: 0.489535
# [175]	train_set's auc: 0.991575	train_set's atec_metric: 0.676656	valid_set's auc: 0.977514	valid_set's atec_metric: 0.488275
# [176]	train_set's auc: 0.991776	train_set's atec_metric: 0.678544	valid_set's auc: 0.977667	valid_set's atec_metric: 0.491376
# [177]	train_set's auc: 0.991835	train_set's atec_metric: 0.67978	valid_set's auc: 0.977676	valid_set's atec_metric: 0.489535
# [178]	train_set's auc: 0.991904	train_set's atec_metric: 0.681212	valid_set's auc: 0.97771	valid_set's atec_metric: 0.488566
# [179]	train_set's auc: 0.991934	train_set's atec_metric: 0.681595	valid_set's auc: 0.977731	valid_set's atec_metric: 0.487403
# [180]	train_set's auc: 0.99196	train_set's atec_metric: 0.68234	valid_set's auc: 0.977735	valid_set's atec_metric: 0.487791
# [181]	train_set's auc: 0.992061	train_set's atec_metric: 0.683056	valid_set's auc: 0.977748	valid_set's atec_metric: 0.489244
# [182]	train_set's auc: 0.992078	train_set's atec_metric: 0.684009	valid_set's auc: 0.977768	valid_set's atec_metric: 0.488663
# [183]	train_set's auc: 0.992096	train_set's atec_metric: 0.683695	valid_set's auc: 0.977776	valid_set's atec_metric: 0.490116
# [184]	train_set's auc: 0.99211	train_set's atec_metric: 0.684928	valid_set's auc: 0.977778	valid_set's atec_metric: 0.490988
# [185]	train_set's auc: 0.99213	train_set's atec_metric: 0.686203	valid_set's auc: 0.97772	valid_set's atec_metric: 0.48905
# [186]	train_set's auc: 0.992154	train_set's atec_metric: 0.686194	valid_set's auc: 0.977719	valid_set's atec_metric: 0.49031
# [187]	train_set's auc: 0.992189	train_set's atec_metric: 0.686719	valid_set's auc: 0.977721	valid_set's atec_metric: 0.492248
# [188]	train_set's auc: 0.992219	train_set's atec_metric: 0.686902	valid_set's auc: 0.977754	valid_set's atec_metric: 0.490698
# [189]	train_set's auc: 0.992411	train_set's atec_metric: 0.687746	valid_set's auc: 0.977821	valid_set's atec_metric: 0.491376
# [190]	train_set's auc: 0.992657	train_set's atec_metric: 0.688302	valid_set's auc: 0.977832	valid_set's atec_metric: 0.494186
# [191]	train_set's auc: 0.992858	train_set's atec_metric: 0.688624	valid_set's auc: 0.977848	valid_set's atec_metric: 0.494864
# [192]	train_set's auc: 0.993047	train_set's atec_metric: 0.689424	valid_set's auc: 0.97789	valid_set's atec_metric: 0.496512
# [193]	train_set's auc: 0.993096	train_set's atec_metric: 0.689905	valid_set's auc: 0.97787	valid_set's atec_metric: 0.494477
# [194]	train_set's auc: 0.993111	train_set's atec_metric: 0.69047	valid_set's auc: 0.977874	valid_set's atec_metric: 0.495446
# [195]	train_set's auc: 0.993172	train_set's atec_metric: 0.692065	valid_set's auc: 0.977871	valid_set's atec_metric: 0.492054
# [196]	train_set's auc: 0.993207	train_set's atec_metric: 0.692141	valid_set's auc: 0.977891	valid_set's atec_metric: 0.494283
# [197]	train_set's auc: 0.993237	train_set's atec_metric: 0.692438	valid_set's auc: 0.977928	valid_set's atec_metric: 0.494477
# [198]	train_set's auc: 0.993275	train_set's atec_metric: 0.693469	valid_set's auc: 0.977951	valid_set's atec_metric: 0.494767
# [199]	train_set's auc: 0.993301	train_set's atec_metric: 0.694377	valid_set's auc: 0.977967	valid_set's atec_metric: 0.497384
# [200]	train_set's auc: 0.993322	train_set's atec_metric: 0.695628	valid_set's auc: 0.977983	valid_set's atec_metric: 0.496415
# [201]	train_set's auc: 0.993397	train_set's atec_metric: 0.696211	valid_set's auc: 0.978035	valid_set's atec_metric: 0.497674
# [202]	train_set's auc: 0.993452	train_set's atec_metric: 0.696788	valid_set's auc: 0.978064	valid_set's atec_metric: 0.49719
# [203]	train_set's auc: 0.993489	train_set's atec_metric: 0.697022	valid_set's auc: 0.978065	valid_set's atec_metric: 0.496512
# [204]	train_set's auc: 0.993522	train_set's atec_metric: 0.697241	valid_set's auc: 0.978064	valid_set's atec_metric: 0.497384
# [205]	train_set's auc: 0.993535	train_set's atec_metric: 0.69739	valid_set's auc: 0.978098	valid_set's atec_metric: 0.495736
# [206]	train_set's auc: 0.993562	train_set's atec_metric: 0.698675	valid_set's auc: 0.978106	valid_set's atec_metric: 0.495446
# [207]	train_set's auc: 0.993599	train_set's atec_metric: 0.698779	valid_set's auc: 0.978084	valid_set's atec_metric: 0.493508
# [208]	train_set's auc: 0.993641	train_set's atec_metric: 0.699232	valid_set's auc: 0.978092	valid_set's atec_metric: 0.494864
# [209]	train_set's auc: 0.993661	train_set's atec_metric: 0.700067	valid_set's auc: 0.978106	valid_set's atec_metric: 0.496512
# [210]	train_set's auc: 0.993685	train_set's atec_metric: 0.700861	valid_set's auc: 0.978124	valid_set's atec_metric: 0.494283
# [211]	train_set's auc: 0.993696	train_set's atec_metric: 0.70189	valid_set's auc: 0.978151	valid_set's atec_metric: 0.493314
# [212]	train_set's auc: 0.993718	train_set's atec_metric: 0.702547	valid_set's auc: 0.978168	valid_set's atec_metric: 0.492636
# [213]	train_set's auc: 0.99374	train_set's atec_metric: 0.702907	valid_set's auc: 0.978175	valid_set's atec_metric: 0.494089
# [214]	train_set's auc: 0.993762	train_set's atec_metric: 0.70446	valid_set's auc: 0.978194	valid_set's atec_metric: 0.492442
# [215]	train_set's auc: 0.993783	train_set's atec_metric: 0.704863	valid_set's auc: 0.978229	valid_set's atec_metric: 0.492636
# [216]	train_set's auc: 0.993828	train_set's atec_metric: 0.70543	valid_set's auc: 0.978246	valid_set's atec_metric: 0.491957
# [217]	train_set's auc: 0.993845	train_set's atec_metric: 0.705849	valid_set's auc: 0.978264	valid_set's atec_metric: 0.490601
# [218]	train_set's auc: 0.993862	train_set's atec_metric: 0.706657	valid_set's auc: 0.978252	valid_set's atec_metric: 0.491085
# [219]	train_set's auc: 0.993874	train_set's atec_metric: 0.706951	valid_set's auc: 0.978247	valid_set's atec_metric: 0.491279
# [220]	train_set's auc: 0.993896	train_set's atec_metric: 0.707343	valid_set's auc: 0.978296	valid_set's atec_metric: 0.49031
# [221]	train_set's auc: 0.99391	train_set's atec_metric: 0.707822	valid_set's auc: 0.978305	valid_set's atec_metric: 0.490019
# [222]	train_set's auc: 0.993926	train_set's atec_metric: 0.709431	valid_set's auc: 0.978313	valid_set's atec_metric: 0.490213
# [223]	train_set's auc: 0.993939	train_set's atec_metric: 0.709647	valid_set's auc: 0.978324	valid_set's atec_metric: 0.492054
# [224]	train_set's auc: 0.993951	train_set's atec_metric: 0.709588	valid_set's auc: 0.978322	valid_set's atec_metric: 0.491764
# [225]	train_set's auc: 0.994033	train_set's atec_metric: 0.709922	valid_set's auc: 0.978328	valid_set's atec_metric: 0.490601
# [226]	train_set's auc: 0.994058	train_set's atec_metric: 0.710476	valid_set's auc: 0.978343	valid_set's atec_metric: 0.490504
# [227]	train_set's auc: 0.994076	train_set's atec_metric: 0.711346	valid_set's auc: 0.978357	valid_set's atec_metric: 0.490698
# [228]	train_set's auc: 0.994089	train_set's atec_metric: 0.713144	valid_set's auc: 0.97841	valid_set's atec_metric: 0.490988
# [229]	train_set's auc: 0.994111	train_set's atec_metric: 0.713637	valid_set's auc: 0.978424	valid_set's atec_metric: 0.489632
# [230]	train_set's auc: 0.994134	train_set's atec_metric: 0.714324	valid_set's auc: 0.978452	valid_set's atec_metric: 0.492926
# [231]	train_set's auc: 0.994149	train_set's atec_metric: 0.715098	valid_set's auc: 0.978488	valid_set's atec_metric: 0.492926
# [232]	train_set's auc: 0.994166	train_set's atec_metric: 0.715857	valid_set's auc: 0.97849	valid_set's atec_metric: 0.492248
# [233]	train_set's auc: 0.994223	train_set's atec_metric: 0.716153	valid_set's auc: 0.978498	valid_set's atec_metric: 0.492248
# [234]	train_set's auc: 0.994238	train_set's atec_metric: 0.716969	valid_set's auc: 0.978493	valid_set's atec_metric: 0.491182
# [235]	train_set's auc: 0.994262	train_set's atec_metric: 0.717475	valid_set's auc: 0.978511	valid_set's atec_metric: 0.490601
# [236]	train_set's auc: 0.994286	train_set's atec_metric: 0.71792	valid_set's auc: 0.978488	valid_set's atec_metric: 0.490213
# [237]	train_set's auc: 0.99431	train_set's atec_metric: 0.7193	valid_set's auc: 0.978512	valid_set's atec_metric: 0.490988
# [238]	train_set's auc: 0.994455	train_set's atec_metric: 0.719352	valid_set's auc: 0.978559	valid_set's atec_metric: 0.490795
# [239]	train_set's auc: 0.994471	train_set's atec_metric: 0.720516	valid_set's auc: 0.978589	valid_set's atec_metric: 0.490795
# [240]	train_set's auc: 0.994498	train_set's atec_metric: 0.721054	valid_set's auc: 0.97858	valid_set's atec_metric: 0.490019
# [241]	train_set's auc: 0.994526	train_set's atec_metric: 0.721549	valid_set's auc: 0.978602	valid_set's atec_metric: 0.490019
# [242]	train_set's auc: 0.994548	train_set's atec_metric: 0.722144	valid_set's auc: 0.97862	valid_set's atec_metric: 0.488953
# [243]	train_set's auc: 0.994572	train_set's atec_metric: 0.722526	valid_set's auc: 0.97864	valid_set's atec_metric: 0.488081
# [244]	train_set's auc: 0.994587	train_set's atec_metric: 0.723545	valid_set's auc: 0.978665	valid_set's atec_metric: 0.487888
# [245]	train_set's auc: 0.994604	train_set's atec_metric: 0.723837	valid_set's auc: 0.978678	valid_set's atec_metric: 0.489244
# [246]	train_set's auc: 0.994637	train_set's atec_metric: 0.724589	valid_set's auc: 0.978686	valid_set's atec_metric: 0.489535
# [247]	train_set's auc: 0.994669	train_set's atec_metric: 0.724832	valid_set's auc: 0.978687	valid_set's atec_metric: 0.491764
# [248]	train_set's auc: 0.9947	train_set's atec_metric: 0.725809	valid_set's auc: 0.978691	valid_set's atec_metric: 0.493217
# [249]	train_set's auc: 0.994726	train_set's atec_metric: 0.726647	valid_set's auc: 0.978712	valid_set's atec_metric: 0.493605
# [250]	train_set's auc: 0.994751	train_set's atec_metric: 0.72788	valid_set's auc: 0.978702	valid_set's atec_metric: 0.495058
# [251]	train_set's auc: 0.994773	train_set's atec_metric: 0.728793	valid_set's auc: 0.978718	valid_set's atec_metric: 0.497287
# [252]	train_set's auc: 0.9948	train_set's atec_metric: 0.728819	valid_set's auc: 0.978726	valid_set's atec_metric: 0.496899
# [253]	train_set's auc: 0.994818	train_set's atec_metric: 0.72891	valid_set's auc: 0.978751	valid_set's atec_metric: 0.497771
# [254]	train_set's auc: 0.994839	train_set's atec_metric: 0.729669	valid_set's auc: 0.978757	valid_set's atec_metric: 0.499612
# [255]	train_set's auc: 0.994852	train_set's atec_metric: 0.729746	valid_set's auc: 0.97874	valid_set's atec_metric: 0.498159
# [256]	train_set's auc: 0.994872	train_set's atec_metric: 0.730689	valid_set's auc: 0.978747	valid_set's atec_metric: 0.497287
# [257]	train_set's auc: 0.994946	train_set's atec_metric: 0.731478	valid_set's auc: 0.978752	valid_set's atec_metric: 0.497384
# [258]	train_set's auc: 0.99502	train_set's atec_metric: 0.732297	valid_set's auc: 0.978761	valid_set's atec_metric: 0.498934
# [259]	train_set's auc: 0.99504	train_set's atec_metric: 0.732842	valid_set's auc: 0.978741	valid_set's atec_metric: 0.499031
# [260]	train_set's auc: 0.995068	train_set's atec_metric: 0.733435	valid_set's auc: 0.978764	valid_set's atec_metric: 0.496318
# [261]	train_set's auc: 0.995097	train_set's atec_metric: 0.733782	valid_set's auc: 0.97877	valid_set's atec_metric: 0.495058
# [262]	train_set's auc: 0.99512	train_set's atec_metric: 0.734611	valid_set's auc: 0.978887	valid_set's atec_metric: 0.497287
# [263]	train_set's auc: 0.995139	train_set's atec_metric: 0.735587	valid_set's auc: 0.978891	valid_set's atec_metric: 0.495058
# [264]	train_set's auc: 0.995158	train_set's atec_metric: 0.736096	valid_set's auc: 0.97891	valid_set's atec_metric: 0.495446
# [265]	train_set's auc: 0.99519	train_set's atec_metric: 0.736911	valid_set's auc: 0.978918	valid_set's atec_metric: 0.495252
# [266]	train_set's auc: 0.995209	train_set's atec_metric: 0.73752	valid_set's auc: 0.978944	valid_set's atec_metric: 0.495155
# [267]	train_set's auc: 0.995259	train_set's atec_metric: 0.73806	valid_set's auc: 0.978971	valid_set's atec_metric: 0.496802
# [268]	train_set's auc: 0.995278	train_set's atec_metric: 0.739388	valid_set's auc: 0.979038	valid_set's atec_metric: 0.49564
# [269]	train_set's auc: 0.995296	train_set's atec_metric: 0.739882	valid_set's auc: 0.979041	valid_set's atec_metric: 0.49438
# [270]	train_set's auc: 0.995314	train_set's atec_metric: 0.740607	valid_set's auc: 0.979053	valid_set's atec_metric: 0.495736
# [271]	train_set's auc: 0.995349	train_set's atec_metric: 0.741145	valid_set's auc: 0.979084	valid_set's atec_metric: 0.496512
# [272]	train_set's auc: 0.995366	train_set's atec_metric: 0.742	valid_set's auc: 0.979086	valid_set's atec_metric: 0.49719
# [273]	train_set's auc: 0.995392	train_set's atec_metric: 0.742552	valid_set's auc: 0.979097	valid_set's atec_metric: 0.496512
# [274]	train_set's auc: 0.995413	train_set's atec_metric: 0.743496	valid_set's auc: 0.9791	valid_set's atec_metric: 0.494961
# [275]	train_set's auc: 0.995435	train_set's atec_metric: 0.743934	valid_set's auc: 0.979107	valid_set's atec_metric: 0.496512
# [276]	train_set's auc: 0.995459	train_set's atec_metric: 0.745187	valid_set's auc: 0.979117	valid_set's atec_metric: 0.494089
# [277]	train_set's auc: 0.995475	train_set's atec_metric: 0.745864	valid_set's auc: 0.979116	valid_set's atec_metric: 0.493702
# [278]	train_set's auc: 0.995495	train_set's atec_metric: 0.746974	valid_set's auc: 0.979131	valid_set's atec_metric: 0.494477
# [279]	train_set's auc: 0.995517	train_set's atec_metric: 0.747763	valid_set's auc: 0.979134	valid_set's atec_metric: 0.494864
# [280]	train_set's auc: 0.995533	train_set's atec_metric: 0.748096	valid_set's auc: 0.979136	valid_set's atec_metric: 0.493702
# [281]	train_set's auc: 0.995551	train_set's atec_metric: 0.748869	valid_set's auc: 0.979251	valid_set's atec_metric: 0.494574
# [282]	train_set's auc: 0.995572	train_set's atec_metric: 0.749631	valid_set's auc: 0.979275	valid_set's atec_metric: 0.495349
# [283]	train_set's auc: 0.995591	train_set's atec_metric: 0.750676	valid_set's auc: 0.979334	valid_set's atec_metric: 0.496415
# [284]	train_set's auc: 0.995605	train_set's atec_metric: 0.750723	valid_set's auc: 0.979453	valid_set's atec_metric: 0.496318
# [285]	train_set's auc: 0.99562	train_set's atec_metric: 0.751071	valid_set's auc: 0.979511	valid_set's atec_metric: 0.496318
# [286]	train_set's auc: 0.995637	train_set's atec_metric: 0.75199	valid_set's auc: 0.979536	valid_set's atec_metric: 0.498353
# [287]	train_set's auc: 0.995661	train_set's atec_metric: 0.752797	valid_set's auc: 0.979556	valid_set's atec_metric: 0.498547
# [288]	train_set's auc: 0.995682	train_set's atec_metric: 0.753491	valid_set's auc: 0.979566	valid_set's atec_metric: 0.497481
# [289]	train_set's auc: 0.995698	train_set's atec_metric: 0.7539	valid_set's auc: 0.979584	valid_set's atec_metric: 0.494961
# [290]	train_set's auc: 0.995712	train_set's atec_metric: 0.75438	valid_set's auc: 0.979584	valid_set's atec_metric: 0.495833
# [291]	train_set's auc: 0.99573	train_set's atec_metric: 0.755159	valid_set's auc: 0.9796	valid_set's atec_metric: 0.493314
# [292]	train_set's auc: 0.995747	train_set's atec_metric: 0.756511	valid_set's auc: 0.979649	valid_set's atec_metric: 0.495155
# [293]	train_set's auc: 0.995762	train_set's atec_metric: 0.757393	valid_set's auc: 0.979654	valid_set's atec_metric: 0.496415
# [294]	train_set's auc: 0.995778	train_set's atec_metric: 0.758152	valid_set's auc: 0.979677	valid_set's atec_metric: 0.498353
# [295]	train_set's auc: 0.995792	train_set's atec_metric: 0.759256	valid_set's auc: 0.979699	valid_set's atec_metric: 0.495543
# [296]	train_set's auc: 0.995813	train_set's atec_metric: 0.760025	valid_set's auc: 0.979705	valid_set's atec_metric: 0.499419
# [297]	train_set's auc: 0.995831	train_set's atec_metric: 0.760871	valid_set's auc: 0.979704	valid_set's atec_metric: 0.499903
# [298]	train_set's auc: 0.995853	train_set's atec_metric: 0.761439	valid_set's auc: 0.979713	valid_set's atec_metric: 0.498934
# [299]	train_set's auc: 0.995874	train_set's atec_metric: 0.76259	valid_set's auc: 0.979704	valid_set's atec_metric: 0.499225
# [300]	train_set's auc: 0.995897	train_set's atec_metric: 0.763634	valid_set's auc: 0.979704	valid_set's atec_metric: 0.498934
# [301]	train_set's auc: 0.99591	train_set's atec_metric: 0.764285	valid_set's auc: 0.979712	valid_set's atec_metric: 0.498837
# [302]	train_set's auc: 0.995926	train_set's atec_metric: 0.764567	valid_set's auc: 0.979709	valid_set's atec_metric: 0.496609
# [303]	train_set's auc: 0.995943	train_set's atec_metric: 0.765184	valid_set's auc: 0.979827	valid_set's atec_metric: 0.49719
# [304]	train_set's auc: 0.996047	train_set's atec_metric: 0.765711	valid_set's auc: 0.97984	valid_set's atec_metric: 0.495543
# [305]	train_set's auc: 0.996062	train_set's atec_metric: 0.765397	valid_set's auc: 0.979849	valid_set's atec_metric: 0.497868
# [306]	train_set's auc: 0.996079	train_set's atec_metric: 0.766685	valid_set's auc: 0.979851	valid_set's atec_metric: 0.500291
# [307]	train_set's auc: 0.996093	train_set's atec_metric: 0.767201	valid_set's auc: 0.979849	valid_set's atec_metric: 0.501163
# [308]	train_set's auc: 0.996108	train_set's atec_metric: 0.767547	valid_set's auc: 0.979869	valid_set's atec_metric: 0.501647
# [309]	train_set's auc: 0.996122	train_set's atec_metric: 0.767748	valid_set's auc: 0.979853	valid_set's atec_metric: 0.502519
# [310]	train_set's auc: 0.996136	train_set's atec_metric: 0.769117	valid_set's auc: 0.979836	valid_set's atec_metric: 0.502132
# [311]	train_set's auc: 0.996149	train_set's atec_metric: 0.769028	valid_set's auc: 0.979833	valid_set's atec_metric: 0.502132
# [312]	train_set's auc: 0.996161	train_set's atec_metric: 0.770014	valid_set's auc: 0.979815	valid_set's atec_metric: 0.500872
# [313]	train_set's auc: 0.996171	train_set's atec_metric: 0.770633	valid_set's auc: 0.979819	valid_set's atec_metric: 0.502132
# [314]	train_set's auc: 0.996184	train_set's atec_metric: 0.7712	valid_set's auc: 0.979809	valid_set's atec_metric: 0.502132
# [315]	train_set's auc: 0.996194	train_set's atec_metric: 0.771712	valid_set's auc: 0.979803	valid_set's atec_metric: 0.502422
# [316]	train_set's auc: 0.996208	train_set's atec_metric: 0.772885	valid_set's auc: 0.979837	valid_set's atec_metric: 0.502422
# [317]	train_set's auc: 0.996229	train_set's atec_metric: 0.77375	valid_set's auc: 0.979911	valid_set's atec_metric: 0.502907
# [318]	train_set's auc: 0.996243	train_set's atec_metric: 0.774846	valid_set's auc: 0.979932	valid_set's atec_metric: 0.502519
# [319]	train_set's auc: 0.996319	train_set's atec_metric: 0.774494	valid_set's auc: 0.979989	valid_set's atec_metric: 0.502326
# [320]	train_set's auc: 0.996333	train_set's atec_metric: 0.775346	valid_set's auc: 0.980018	valid_set's atec_metric: 0.502035
# [321]	train_set's auc: 0.996354	train_set's atec_metric: 0.775785	valid_set's auc: 0.980005	valid_set's atec_metric: 0.502422
# [322]	train_set's auc: 0.996366	train_set's atec_metric: 0.776409	valid_set's auc: 0.980068	valid_set's atec_metric: 0.503101
# [323]	train_set's auc: 0.996377	train_set's atec_metric: 0.776319	valid_set's auc: 0.980067	valid_set's atec_metric: 0.503391
# [324]	train_set's auc: 0.996389	train_set's atec_metric: 0.776893	valid_set's auc: 0.980062	valid_set's atec_metric: 0.502519
# [325]	train_set's auc: 0.996403	train_set's atec_metric: 0.77698	valid_set's auc: 0.980047	valid_set's atec_metric: 0.503198
# [326]	train_set's auc: 0.996415	train_set's atec_metric: 0.77717	valid_set's auc: 0.980037	valid_set's atec_metric: 0.502229
# [327]	train_set's auc: 0.996425	train_set's atec_metric: 0.778287	valid_set's auc: 0.980023	valid_set's atec_metric: 0.50281
# [328]	train_set's auc: 0.996434	train_set's atec_metric: 0.778691	valid_set's auc: 0.980028	valid_set's atec_metric: 0.503488
# [329]	train_set's auc: 0.996446	train_set's atec_metric: 0.779202	valid_set's auc: 0.980013	valid_set's atec_metric: 0.502713
# [330]	train_set's auc: 0.99646	train_set's atec_metric: 0.780453	valid_set's auc: 0.980009	valid_set's atec_metric: 0.503391
# [331]	train_set's auc: 0.996482	train_set's atec_metric: 0.781139	valid_set's auc: 0.980005	valid_set's atec_metric: 0.503585
# [332]	train_set's auc: 0.996495	train_set's atec_metric: 0.7814	valid_set's auc: 0.980016	valid_set's atec_metric: 0.503295
# [333]	train_set's auc: 0.996506	train_set's atec_metric: 0.781839	valid_set's auc: 0.980024	valid_set's atec_metric: 0.50436
# [334]	train_set's auc: 0.996518	train_set's atec_metric: 0.782527	valid_set's auc: 0.980024	valid_set's atec_metric: 0.50436
# [335]	train_set's auc: 0.996535	train_set's atec_metric: 0.783094	valid_set's auc: 0.980024	valid_set's atec_metric: 0.503973
# [336]	train_set's auc: 0.996546	train_set's atec_metric: 0.783668	valid_set's auc: 0.980034	valid_set's atec_metric: 0.504264
# [337]	train_set's auc: 0.996561	train_set's atec_metric: 0.783698	valid_set's auc: 0.980048	valid_set's atec_metric: 0.503876
# [338]	train_set's auc: 0.996571	train_set's atec_metric: 0.784639	valid_set's auc: 0.980064	valid_set's atec_metric: 0.504167
# [339]	train_set's auc: 0.996587	train_set's atec_metric: 0.78543	valid_set's auc: 0.980071	valid_set's atec_metric: 0.504748
# [340]	train_set's auc: 0.99662	train_set's atec_metric: 0.786004	valid_set's auc: 0.98009	valid_set's atec_metric: 0.503779
# [341]	train_set's auc: 0.99663	train_set's atec_metric: 0.786578	valid_set's auc: 0.980093	valid_set's atec_metric: 0.504167
# [342]	train_set's auc: 0.996641	train_set's atec_metric: 0.787314	valid_set's auc: 0.980021	valid_set's atec_metric: 0.504457
# [343]	train_set's auc: 0.996668	train_set's atec_metric: 0.787807	valid_set's auc: 0.980036	valid_set's atec_metric: 0.504845
# [344]	train_set's auc: 0.996681	train_set's atec_metric: 0.788155	valid_set's auc: 0.980053	valid_set's atec_metric: 0.503876
# [345]	train_set's auc: 0.996689	train_set's atec_metric: 0.788579	valid_set's auc: 0.98007	valid_set's atec_metric: 0.504845
# [346]	train_set's auc: 0.996697	train_set's atec_metric: 0.789273	valid_set's auc: 0.980064	valid_set's atec_metric: 0.504457
# [347]	train_set's auc: 0.996745	train_set's atec_metric: 0.789812	valid_set's auc: 0.980063	valid_set's atec_metric: 0.503876
# [348]	train_set's auc: 0.996754	train_set's atec_metric: 0.790023	valid_set's auc: 0.980065	valid_set's atec_metric: 0.503585
# [349]	train_set's auc: 0.996768	train_set's atec_metric: 0.790533	valid_set's auc: 0.980063	valid_set's atec_metric: 0.503004
# [350]	train_set's auc: 0.996778	train_set's atec_metric: 0.79123	valid_set's auc: 0.98006	valid_set's atec_metric: 0.502713
# [351]	train_set's auc: 0.996791	train_set's atec_metric: 0.791973	valid_set's auc: 0.980062	valid_set's atec_metric: 0.503004
# [352]	train_set's auc: 0.996799	train_set's atec_metric: 0.792555	valid_set's auc: 0.980139	valid_set's atec_metric: 0.503391
# [353]	train_set's auc: 0.996811	train_set's atec_metric: 0.792917	valid_set's auc: 0.980152	valid_set's atec_metric: 0.503391
# [354]	train_set's auc: 0.996821	train_set's atec_metric: 0.793735	valid_set's auc: 0.980152	valid_set's atec_metric: 0.503391
# [355]	train_set's auc: 0.996834	train_set's atec_metric: 0.794388	valid_set's auc: 0.980152	valid_set's atec_metric: 0.504457
# [356]	train_set's auc: 0.996842	train_set's atec_metric: 0.794883	valid_set's auc: 0.980154	valid_set's atec_metric: 0.504457
# [357]	train_set's auc: 0.99685	train_set's atec_metric: 0.795378	valid_set's auc: 0.98016	valid_set's atec_metric: 0.504457
# [358]	train_set's auc: 0.99686	train_set's atec_metric: 0.796457	valid_set's auc: 0.980168	valid_set's atec_metric: 0.504457
# [359]	train_set's auc: 0.996869	train_set's atec_metric: 0.796805	valid_set's auc: 0.980175	valid_set's atec_metric: 0.504845
# [360]	train_set's auc: 0.996882	train_set's atec_metric: 0.797384	valid_set's auc: 0.980199	valid_set's atec_metric: 0.504457
# [361]	train_set's auc: 0.996891	train_set's atec_metric: 0.798044	valid_set's auc: 0.980207	valid_set's atec_metric: 0.503682
# [362]	train_set's auc: 0.996898	train_set's atec_metric: 0.79828	valid_set's auc: 0.980127	valid_set's atec_metric: 0.504264
# [363]	train_set's auc: 0.996907	train_set's atec_metric: 0.799269	valid_set's auc: 0.980135	valid_set's atec_metric: 0.503779
# [364]	train_set's auc: 0.996914	train_set's atec_metric: 0.800021	valid_set's auc: 0.980137	valid_set's atec_metric: 0.502907
# [365]	train_set's auc: 0.996923	train_set's atec_metric: 0.800362	valid_set's auc: 0.980135	valid_set's atec_metric: 0.503004
# [366]	train_set's auc: 0.996933	train_set's atec_metric: 0.800972	valid_set's auc: 0.980145	valid_set's atec_metric: 0.502519
# [367]	train_set's auc: 0.996943	train_set's atec_metric: 0.801209	valid_set's auc: 0.980139	valid_set's atec_metric: 0.502713
# [368]	train_set's auc: 0.996951	train_set's atec_metric: 0.801654	valid_set's auc: 0.980145	valid_set's atec_metric: 0.50155
# [369]	train_set's auc: 0.996961	train_set's atec_metric: 0.802049	valid_set's auc: 0.980153	valid_set's atec_metric: 0.500969
# [370]	train_set's auc: 0.99697	train_set's atec_metric: 0.802439	valid_set's auc: 0.980151	valid_set's atec_metric: 0.502132
# [371]	train_set's auc: 0.996977	train_set's atec_metric: 0.802811	valid_set's auc: 0.98014	valid_set's atec_metric: 0.501744
# [372]	train_set's auc: 0.996985	train_set's atec_metric: 0.803383	valid_set's auc: 0.980131	valid_set's atec_metric: 0.500484
# [373]	train_set's auc: 0.997033	train_set's atec_metric: 0.804006	valid_set's auc: 0.980123	valid_set's atec_metric: 0.501163
# [374]	train_set's auc: 0.99704	train_set's atec_metric: 0.804361	valid_set's auc: 0.98013	valid_set's atec_metric: 0.501938
# [375]	train_set's auc: 0.997049	train_set's atec_metric: 0.804902	valid_set's auc: 0.980148	valid_set's atec_metric: 0.50281
# [376]	train_set's auc: 0.997057	train_set's atec_metric: 0.805515	valid_set's auc: 0.980139	valid_set's atec_metric: 0.502229
# [377]	train_set's auc: 0.997065	train_set's atec_metric: 0.806164	valid_set's auc: 0.980132	valid_set's atec_metric: 0.500484
# [378]	train_set's auc: 0.997074	train_set's atec_metric: 0.806434	valid_set's auc: 0.980122	valid_set's atec_metric: 0.501453
# [379]	train_set's auc: 0.997083	train_set's atec_metric: 0.806577	valid_set's auc: 0.980116	valid_set's atec_metric: 0.500872
# [380]	train_set's auc: 0.997092	train_set's atec_metric: 0.807147	valid_set's auc: 0.980107	valid_set's atec_metric: 0.500194
# [381]	train_set's auc: 0.997101	train_set's atec_metric: 0.807662	valid_set's auc: 0.980117	valid_set's atec_metric: 0.500388
# [382]	train_set's auc: 0.99711	train_set's atec_metric: 0.808548	valid_set's auc: 0.980123	valid_set's atec_metric: 0.499612
# [383]	train_set's auc: 0.997122	train_set's atec_metric: 0.809275	valid_set's auc: 0.980123	valid_set's atec_metric: 0.500388
# [384]	train_set's auc: 0.997133	train_set's atec_metric: 0.810016	valid_set's auc: 0.98013	valid_set's atec_metric: 0.501066
# [385]	train_set's auc: 0.997143	train_set's atec_metric: 0.810343	valid_set's auc: 0.980137	valid_set's atec_metric: 0.50281
# [386]	train_set's auc: 0.997151	train_set's atec_metric: 0.810917	valid_set's auc: 0.980133	valid_set's atec_metric: 0.502616
# [387]	train_set's auc: 0.997159	train_set's atec_metric: 0.810942	valid_set's auc: 0.980114	valid_set's atec_metric: 0.502132
# [388]	train_set's auc: 0.997167	train_set's atec_metric: 0.811867	valid_set's auc: 0.980105	valid_set's atec_metric: 0.503295
# [389]	train_set's auc: 0.997174	train_set's atec_metric: 0.812298	valid_set's auc: 0.980101	valid_set's atec_metric: 0.50281
# [390]	train_set's auc: 0.997183	train_set's atec_metric: 0.813058	valid_set's auc: 0.980109	valid_set's atec_metric: 0.502713
# [391]	train_set's auc: 0.997228	train_set's atec_metric: 0.813575	valid_set's auc: 0.979913	valid_set's atec_metric: 0.502422
# [392]	train_set's auc: 0.997248	train_set's atec_metric: 0.813769	valid_set's auc: 0.979614	valid_set's atec_metric: 0.502035
# [393]	train_set's auc: 0.997257	train_set's atec_metric: 0.814203	valid_set's auc: 0.979613	valid_set's atec_metric: 0.503682
# [394]	train_set's auc: 0.997265	train_set's atec_metric: 0.815154	valid_set's auc: 0.979634	valid_set's atec_metric: 0.503391
# [395]	train_set's auc: 0.997279	train_set's atec_metric: 0.81575	valid_set's auc: 0.979107	valid_set's atec_metric: 0.503004
# [396]	train_set's auc: 0.997287	train_set's atec_metric: 0.815842	valid_set's auc: 0.979117	valid_set's atec_metric: 0.503973
# [397]	train_set's auc: 0.997296	train_set's atec_metric: 0.816302	valid_set's auc: 0.97912	valid_set's atec_metric: 0.505039
# [398]	train_set's auc: 0.997302	train_set's atec_metric: 0.816964	valid_set's auc: 0.979115	valid_set's atec_metric: 0.50436
# [399]	train_set's auc: 0.99731	train_set's atec_metric: 0.817415	valid_set's auc: 0.979121	valid_set's atec_metric: 0.503488
# [400]	train_set's auc: 0.997317	train_set's atec_metric: 0.818126	valid_set's auc: 0.979101	valid_set's atec_metric: 0.504167
# [401]	train_set's auc: 0.997325	train_set's atec_metric: 0.818548	valid_set's auc: 0.979087	valid_set's atec_metric: 0.503391
# [402]	train_set's auc: 0.997333	train_set's atec_metric: 0.81865	valid_set's auc: 0.97908	valid_set's atec_metric: 0.502326
# [403]	train_set's auc: 0.997339	train_set's atec_metric: 0.819034	valid_set's auc: 0.97907	valid_set's atec_metric: 0.502519
# [404]	train_set's auc: 0.997346	train_set's atec_metric: 0.81946	valid_set's auc: 0.979092	valid_set's atec_metric: 0.502326
# [405]	train_set's auc: 0.997353	train_set's atec_metric: 0.819974	valid_set's auc: 0.97908	valid_set's atec_metric: 0.503876
# [406]	train_set's auc: 0.997364	train_set's atec_metric: 0.820691	valid_set's auc: 0.978749	valid_set's atec_metric: 0.503488
# [407]	train_set's auc: 0.997375	train_set's atec_metric: 0.821757	valid_set's auc: 0.978594	valid_set's atec_metric: 0.50436
# [408]	train_set's auc: 0.997384	train_set's atec_metric: 0.822026	valid_set's auc: 0.978217	valid_set's atec_metric: 0.503973
# [409]	train_set's auc: 0.99743	train_set's atec_metric: 0.82217	valid_set's auc: 0.978228	valid_set's atec_metric: 0.503973
# [410]	train_set's auc: 0.99744	train_set's atec_metric: 0.823046	valid_set's auc: 0.977992	valid_set's atec_metric: 0.502519
# [411]	train_set's auc: 0.997447	train_set's atec_metric: 0.823344	valid_set's auc: 0.978004	valid_set's atec_metric: 0.504167
# [412]	train_set's auc: 0.997455	train_set's atec_metric: 0.824022	valid_set's auc: 0.978022	valid_set's atec_metric: 0.504845
# [413]	train_set's auc: 0.99746	train_set's atec_metric: 0.824727	valid_set's auc: 0.978035	valid_set's atec_metric: 0.50436
# [414]	train_set's auc: 0.997486	train_set's atec_metric: 0.825274	valid_set's auc: 0.97804	valid_set's atec_metric: 0.503682
# [415]	train_set's auc: 0.997491	train_set's atec_metric: 0.82536	valid_set's auc: 0.978016	valid_set's atec_metric: 0.50407
# [416]	train_set's auc: 0.9975	train_set's atec_metric: 0.825467	valid_set's auc: 0.978048	valid_set's atec_metric: 0.50407
# [417]	train_set's auc: 0.997611	train_set's atec_metric: 0.826071	valid_set's auc: 0.978286	valid_set's atec_metric: 0.504554
# [418]	train_set's auc: 0.997628	train_set's atec_metric: 0.826084	valid_set's auc: 0.978286	valid_set's atec_metric: 0.503585
# [419]	train_set's auc: 0.997658	train_set's atec_metric: 0.827254	valid_set's auc: 0.97832	valid_set's atec_metric: 0.503488
# [420]	train_set's auc: 0.997665	train_set's atec_metric: 0.82767	valid_set's auc: 0.978312	valid_set's atec_metric: 0.503101
# [421]	train_set's auc: 0.997671	train_set's atec_metric: 0.828802	valid_set's auc: 0.978325	valid_set's atec_metric: 0.503876
# [422]	train_set's auc: 0.997678	train_set's atec_metric: 0.828868	valid_set's auc: 0.978346	valid_set's atec_metric: 0.504264
# [423]	train_set's auc: 0.997686	train_set's atec_metric: 0.82954	valid_set's auc: 0.9781	valid_set's atec_metric: 0.503295
# [424]	train_set's auc: 0.997697	train_set's atec_metric: 0.830142	valid_set's auc: 0.978104	valid_set's atec_metric: 0.504457
# [425]	train_set's auc: 0.997703	train_set's atec_metric: 0.831055	valid_set's auc: 0.978107	valid_set's atec_metric: 0.503391
# [426]	train_set's auc: 0.99771	train_set's atec_metric: 0.831316	valid_set's auc: 0.978121	valid_set's atec_metric: 0.503004
# [427]	train_set's auc: 0.997718	train_set's atec_metric: 0.832052	valid_set's auc: 0.978128	valid_set's atec_metric: 0.501938
# [428]	train_set's auc: 0.997723	train_set's atec_metric: 0.8323	valid_set's auc: 0.978115	valid_set's atec_metric: 0.502229
# [429]	train_set's auc: 0.997732	train_set's atec_metric: 0.832859	valid_set's auc: 0.978123	valid_set's atec_metric: 0.501647
# [430]	train_set's auc: 0.997739	train_set's atec_metric: 0.83296	valid_set's auc: 0.978136	valid_set's atec_metric: 0.501647
# [431]	train_set's auc: 0.997767	train_set's atec_metric: 0.833341	valid_set's auc: 0.97812	valid_set's atec_metric: 0.501647
# [432]	train_set's auc: 0.997794	train_set's atec_metric: 0.833575	valid_set's auc: 0.97811	valid_set's atec_metric: 0.50126
# [433]	train_set's auc: 0.997809	train_set's atec_metric: 0.834136	valid_set's auc: 0.978105	valid_set's atec_metric: 0.501647
# [434]	train_set's auc: 0.99798	train_set's atec_metric: 0.83501	valid_set's auc: 0.978121	valid_set's atec_metric: 0.501938
# [435]	train_set's auc: 0.998003	train_set's atec_metric: 0.835224	valid_set's auc: 0.978121	valid_set's atec_metric: 0.50126
# [436]	train_set's auc: 0.998049	train_set's atec_metric: 0.835748	valid_set's auc: 0.978104	valid_set's atec_metric: 0.501647
# [437]	train_set's auc: 0.998062	train_set's atec_metric: 0.836151	valid_set's auc: 0.978169	valid_set's atec_metric: 0.502035
# [438]	train_set's auc: 0.998069	train_set's atec_metric: 0.836369	valid_set's auc: 0.977611	valid_set's atec_metric: 0.500969
# [439]	train_set's auc: 0.998078	train_set's atec_metric: 0.836742	valid_set's auc: 0.977594	valid_set's atec_metric: 0.500969
# [440]	train_set's auc: 0.998085	train_set's atec_metric: 0.837375	valid_set's auc: 0.977406	valid_set's atec_metric: 0.500969
# [441]	train_set's auc: 0.998091	train_set's atec_metric: 0.838142	valid_set's auc: 0.977401	valid_set's atec_metric: 0.499709
# [442]	train_set's auc: 0.998098	train_set's atec_metric: 0.838765	valid_set's auc: 0.977401	valid_set's atec_metric: 0.502326
# [443]	train_set's auc: 0.998105	train_set's atec_metric: 0.839132	valid_set's auc: 0.977442	valid_set's atec_metric: 0.501066
# [444]	train_set's auc: 0.998118	train_set's atec_metric: 0.839481	valid_set's auc: 0.977452	valid_set's atec_metric: 0.500872
# [445]	train_set's auc: 0.998127	train_set's atec_metric: 0.839935	valid_set's auc: 0.977476	valid_set's atec_metric: 0.499612
# [446]	train_set's auc: 0.998147	train_set's atec_metric: 0.840464	valid_set's auc: 0.977477	valid_set's atec_metric: 0.499516
# [447]	train_set's auc: 0.99816	train_set's atec_metric: 0.840847	valid_set's auc: 0.977463	valid_set's atec_metric: 0.499806
# [448]	train_set's auc: 0.998177	train_set's atec_metric: 0.841379	valid_set's auc: 0.977482	valid_set's atec_metric: 0.500388
# [449]	train_set's auc: 0.998189	train_set's atec_metric: 0.8422	valid_set's auc: 0.977505	valid_set's atec_metric: 0.499128
# [450]	train_set's auc: 0.998195	train_set's atec_metric: 0.842759	valid_set's auc: 0.97752	valid_set's atec_metric: 0.499128
# [451]	train_set's auc: 0.998219	train_set's atec_metric: 0.84321	valid_set's auc: 0.977474	valid_set's atec_metric: 0.499516
# [452]	train_set's auc: 0.998254	train_set's atec_metric: 0.844155	valid_set's auc: 0.977496	valid_set's atec_metric: 0.499128
# [453]	train_set's auc: 0.998265	train_set's atec_metric: 0.844658	valid_set's auc: 0.977467	valid_set's atec_metric: 0.498837
# [454]	train_set's auc: 0.998273	train_set's atec_metric: 0.845143	valid_set's auc: 0.977462	valid_set's atec_metric: 0.498547
# [455]	train_set's auc: 0.998279	train_set's atec_metric: 0.8457	valid_set's auc: 0.977477	valid_set's atec_metric: 0.49874
# [456]	train_set's auc: 0.998285	train_set's atec_metric: 0.845886	valid_set's auc: 0.9775	valid_set's atec_metric: 0.497771
# [457]	train_set's auc: 0.998292	train_set's atec_metric: 0.846344	valid_set's auc: 0.977523	valid_set's atec_metric: 0.498159
# [458]	train_set's auc: 0.998298	train_set's atec_metric: 0.847035	valid_set's auc: 0.977558	valid_set's atec_metric: 0.497868
# [459]	train_set's auc: 0.998307	train_set's atec_metric: 0.8472	valid_set's auc: 0.977561	valid_set's atec_metric: 0.497868
# [460]	train_set's auc: 0.998324	train_set's atec_metric: 0.847726	valid_set's auc: 0.977594	valid_set's atec_metric: 0.496609
# [461]	train_set's auc: 0.998329	train_set's atec_metric: 0.848193	valid_set's auc: 0.977603	valid_set's atec_metric: 0.496124
# Early stopping, best iteration is:
# [361]	train_set's auc: 0.996891	train_set's atec_metric: 0.798044	valid_set's auc: 0.980207	valid_set's atec_metric: 0.503682
